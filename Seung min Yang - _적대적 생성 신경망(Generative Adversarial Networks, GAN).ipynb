# %% [markdown]
# - 내용 및 코드 참조
#
#   - 케라스 창시자로부터 배우는 딥러닝
#
#   - 미술관에 GAN 딥러닝 실전 프로젝트

# %% [markdown]
# # 적대적 생성 신경망(Generative Adversarial Networks, GAN)
#
# - 2014년, Ian Goodfellow 소개
#
# - VAE와는 다른 방법으로 이미지 잠재 공간을 학습
#
# - 직관적으로 이해하는 방법
#
#   - 가짜 피카소 그림을 그리는 위조범과 이를 판별하는 판매상의 관계
#
#   - 위조품과 진짜 그림을 섞어서 판매상에게 보여주며
#     그림이 진짜인지 가짜인지 판매상은 판별하고 이를 위조범에게 피드백
#
#   - 처음에는 형편없는 그림을 그리다가 점점 피카소의 스타일을 모방하게 되고
#     판매상은 위조품을 구분하는데 점점 더 전문가가 되어감
#
# - GAN의 네트워크
#
#   - 생성자 네트워크(generator network)
#
#     - 랜덤 벡터(잠재 공간의 무작위한 포인트)를 입력으로 받아 이를 합성된 이미지로 디코딩
#
#   - 판별자 네트워크(discriminator netowrk)
#
#     - 이미지(실제 또는 가짜 이미지)를 입력으로 받아 훈련 세트에서 온 이미지인지 생성자가 만든 이미지인지 판별
#
# - GAN은 최적화의 최솟값이 고정되어 있지 않음
#
#   - 보통의 경사하강법은 **고정된 손실공간**에서 언덕을 내려오는 훈련 방법이지만
#     GAN은 매 단계가 조금씩 전체 공간을 바꾸기 때문에 최적화 과정이 최솟값을 찾는 것이 어려움
#
#   - 두 힘간의 평형점을 찾는 시스템
#
#   - 따라서, 학습과정이 매우 어려움
#     즉, 적절한 파라미터를 찾고 조정해야함
#
#   <img src="https://paperswithcode.com/media/methods/gan.jpeg">
#
#   <sub>[이미지 출처] https://paperswithcode.com/method/gan</sub>

# %% [markdown]
# ## GAN의 구현 (DCGAN)
#
# - CIFAR10 데이터셋 사용
#
# - generator 네트워크는 (latent_dim,) 크기의 벡터를 (32, 32, 3) 크기의 이미지로 매핑
#
# - discriminator 네트워크는 (32, 32, 3) 크기의 이미지가 진짜일 확률을 추정하여 이진값으로 매핑
#
# - 생성자와 판별자를 연결하는 gan 네트워크를 만듬
#
#   - gan(x) = discriminator(generator(x))
#
# - 진짜/가짜 레이블과 함께 진짜 이미지와 가짜 이미지 샘플을 사용하여 판별자를 훈련 (일반적인 이미지 분류 모델 훈련과 동일)
#
# - 생성자를 훈련하려면 gan 모델의 손실에 대한 생성자 가중치의 그래디언트를 사용
#
#   - 매 단계마다 생성자에 의해 디코딩된 이미지를 판별자가 "진짜"로 분류하도록 만다는 방향으로 생성자의 가중치를 이동
#
#   - 판별자를 속이도록 생성자를 훈련한다는 말

# %% [markdown]
# ## 학습 방법
#
# - 마지막 활성화 함수로 sigmoid 대신 tanh함수 사용
#
# - 균등분포가 아니고 정규 분포(가우시안 분포)를 사용하여 잠재 공간에서 포인트를 샘플링
#
# - 무작위성을 주입
#
#   - 판별자에 드롭아웃을 사용
#
#   - 판별자를 위해 레이블에 랜덤 노이즈를 추가
#
# - 희소한 그래디언트는 GAN 훈련에 방해가 될 수 있음
#
#   - 최대 풀링 대신 스트라이드 합성곱을 사용하여 다운샘플링
#
#   - ReLU 대신 LeakyReLU 사용
#
# - 생성자에서 픽셀 공간을 균일하게 다루지 못하여 생성된 이미지에서 체스판 모양이 종종 나타남.
#   이를 위해 생성자와 판별자에서 스트라이드 Conv2DTranpose나 Conv2D를 사용할 때 스트라이드 크기로 나누어 질 수 있는 커널 크기 사용
#
#   - 커널 크기가 스트라이드의 배수가 아니면 픽셀이 공평하게 합성곱 되지 않음
#     커널 크기를 스트라이드로 나누었을 때 나머지 크기에 해당하는 픽셀이 더 많이 업샘플링에 참여하게 됨

# %% [markdown]
# ### GAN 생성자 네트워크

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input , Dense, LeakyReLU, Reshape, Conv2D, Conv2DTranspose, Flatten, Dropout
from tensorflow.keras.models import Model
import numpy as np

# %%
latent_dim = 32
height =32
width = 32
channels= 3

# %%
generator_input = Input(shape=(latent_dim, ))

# %%
x = Dense(128 * 16 * 16)(generator_input)
x = LeakyReLU()(x)
x = Reshape((16, 16, 128))(x)

x = Conv2D(256, 5, padding='same')(x)
x = LeakyReLU()(x)

x = Conv2DTranspose(256, 4, strides =2, padding='same')(x)
x = LeakyReLU()(x)

x = Conv2D(256, 5, padding='same')(x)
x = LeakyReLU()(x)
x = Conv2D(256, 5, padding='same')(x)
x = LeakyReLU()(x)

x = Conv2D(channels, 7 , activation='tanh', padding='same')(x)

# %%
generator = Model(generator_input, x)
generator.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32)]              0
# _________________________________________________________________
# dense (Dense)                (None, 32768)             1081344
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 32768)             0
# _________________________________________________________________
# reshape (Reshape)            (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 16, 16, 256)       819456
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 32, 32, 256)       1048832
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 3)         37635
# =================================================================
# Total params: 6,264,579
# Trainable params: 6,264,579
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### GAN 판별자 네트워크

# %%
discriminator_input = Input(shape=(height, width, channels))

# %%
x = Conv2D(128 ,3)(discriminator_input)
x=  LeakyReLU()(x)
x = Conv2D(128 ,4, strides=2)(x)
x=  LeakyReLU()(x)
x = Conv2D(128, 4, strides=2)(x)
x=  LeakyReLU()(x)
x = Conv2D(128, 4, strides=2)(x)
x=  LeakyReLU()(x)
x = Flatten()(x)
x = Dropout(.4)(x)
x = Dense(1, activation='sigmoid')(x)

# %%
discriminator = Model(discriminator_input, x)
discriminator.summary()
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 30, 30, 128)       3584
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 14, 14, 128)       262272
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 6, 6, 128)         262272
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 2, 2, 128)         262272
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 790,913
# Trainable params: 790,913
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop

# %%
discriminator_optimizer = RMSprop(lr=0.0008, clipvalue=1.0, decay=1e-8)
discriminator.compile(optimizer = discriminator_optimizer, loss='binary_crossentropy')

# %% [markdown]
# ### 적대적 네트워크
# - 생성자와 판별자를 연결
#
# - 훈련할 때 생성자가 판별자를 속이는 능력이 커지도록 학습
#
# - 잠재 공간의 포인트를 진짜 또는 가짜의 분류 결정으로 변환
#
# - 훈련에 사용되는 target label은 항상 "진짜 이미지"
#
# - 훈련하는 동안 판별자를 동결(학습되지 않도록)하는 것이 매우 중요!
#
#   - 판별자의 가중치가 훈련하는 동안 업데이트되면 판별자는 항상 진짜를 예측하도록 훈련됨

# %%
discriminator.trainable = False

gan_input = Input(shape=(latent_dim, ))
gan_output = discriminator(generator(gan_input))
gan = Model(gan_input, gan_output)

gan_optimizer = RMSprop(lr = 0.0004, clipvalue=1.0, decay=1e-8)
gan.compile(optimizer=gan_optimizer, loss='binary_crossentropy')

# %% [markdown]
# ### GAN 훈련 구현
#
# - DCGAN 구현
#
# - 매 반복마다 아래의 과정 수행
#
#   1. 잠재 공간에서 무작위로 포인트를 뽑음(랜덤 노이즈)
#
#   2. 랜덤 노이즈를 사용하여 generator에서 이미지를 생성
#
#   3. 생성된 이미지와 진짜 이미지를 섞음
#
#   4. 진짜와 가짜가 섞인 이미지와 이에 대응하는 타깃을 사용하여 discriminator를 훈련
#     타킷은 진짜 또는 가짜
#
#   5. 잠재 공간에서 무작위로 새로운 포인트를 뽑음
#
#   6. 랜덤 벡터를 사용하여 gan을 훈련.
#     모든 타깃은 진짜로 설정.
#     - 판별자가 생성된 이미지를 모두 "진짜 이미지"라고 예측하도록 생성자의 가중치를 업데이트.
#       (판별자는 동결되기 때문에 생성자만 업데이트)

# %%
import os
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing import image

# %% [markdown]
# #### CIFAR10 데이터 로드

# %%
(x_train, y_train), (_,_) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step

# %% [markdown]
# #### 개구리 이미지를 선택

# %%
x_train = x_train[y_train.flatten() == 6]

# %% [markdown]
# #### 데이터 정규화

# %%
x_train = x_train.reshape((x_train.shape[0], ) + (height, width, channels)).astype('float32') / 255.

# %%
iterator = 10000
batch_size = 20

save_dir = '/content/gan_images/'
if not os.path.exists(save_dir):
  os.mkdir(save_dir)

# %% [markdown]
# #### 학습

# %%
start = 0
for step in range(iterator):
  random_latent_vectors =  np.random.normal(size=(batch_size, latent_dim))
  generated_images = generator.predict(random_latent_vectors)

  stop = start + batch_size
  real_images = x_train[start:stop]
  combined_images=  np.concatenate([generated_images, real_images])

  labels = np.concatenate([np.ones((batch_size, 1)),
                           np.zeros((batch_size, 1))])
  
  labels += 0.05 * np.random.random(labels.shape)

  d_loss = discriminator.train_on_batch(combined_images, labels)

  random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))
  misleading_targets = np.zeros((batch_size, 1))

  a_loss = gan.train_on_batch(random_latent_vectors, misleading_targets)

  start += batch_size
  if start > len(x_train) -batch_size:
    start = 0
  
  if stop % 100 == 0:
    gan.save_weights('gan.h5')

    print('\nstep: {}'.format(step))
    print("discriminator loss: {}".format(d_loss))
    print('adversarial loss: {}'.format(a_loss))

    img = image.array_to_img(generated_images[0] * 255., scale=False)
    img.save(os.path.join(save_dir, 'generated_frog' + str(step) + '.png'))
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#
# step: 3754
# discriminator loss: 0.6981008052825928
# adversarial loss: 0.7354048490524292
#
# step: 3759
# discriminator loss: 0.691897988319397
# adversarial loss: 0.7328685522079468
#
# step: 3764
# discriminator loss: 0.6793419718742371
# adversarial loss: 0.7116079926490784
#
# step: 3769
# discriminator loss: 0.988660454750061
# adversarial loss: 0.9489920735359192
#
# step: 3774
# discriminator loss: 0.6808484196662903
# adversarial loss: 0.7638409733772278
#
# step: 3779
# discriminator loss: 0.6909661293029785
# adversarial loss: 0.7262176275253296
#
# step: 3784
# discriminator loss: 0.7162857055664062
# adversarial loss: 0.7757092118263245
#
# step: 3789
# discriminator loss: 0.6964951753616333
# adversarial loss: 0.7591514587402344
#
# step: 3794
# discriminator loss: 0.6967894434928894
# adversarial loss: 0.7468002438545227
#
# step: 3799
# discriminator loss: 0.7005037665367126
# adversarial loss: 0.739273726940155
#
# step: 3804
# discriminator loss: 0.6815177798271179
# adversarial loss: 0.7270444631576538
#
# step: 3809
# discriminator loss: 0.6852402687072754
# adversarial loss: 0.756390392780304
#
# step: 3814
# discriminator loss: 0.7022979259490967
# adversarial loss: 0.7417547106742859
#
# step: 3819
# discriminator loss: 0.8934941291809082
# adversarial loss: 0.8507562875747681
#
# step: 3824
# discriminator loss: 0.6989848017692566
# adversarial loss: 0.7507301568984985
#
# step: 3829
# discriminator loss: 0.691770076751709
# adversarial loss: 0.7611702680587769
#
# step: 3834
# discriminator loss: 0.6793750524520874
# adversarial loss: 0.7495562434196472
#
# step: 3839
# discriminator loss: 0.6786149740219116
# adversarial loss: 0.7662078142166138
#
# step: 3844
# discriminator loss: 0.6776782274246216
# adversarial loss: 0.8548700213432312
#
# step: 3849
# discriminator loss: 0.7169760465621948
# adversarial loss: 0.7333868741989136
#
# step: 3854
# discriminator loss: 0.6796862483024597
# adversarial loss: 0.7537896037101746
#
# step: 3859
# discriminator loss: 0.6851643323898315
# adversarial loss: 0.758624792098999
#
# step: 3864
# discriminator loss: 0.7174373865127563
# adversarial loss: 0.7925598621368408
#
# step: 3869
# discriminator loss: 0.700617790222168
# adversarial loss: 0.748092532157898
#
# step: 3874
# discriminator loss: 0.700411856174469
# adversarial loss: 0.7301457524299622
#
# step: 3879
# discriminator loss: 0.6954048275947571
# adversarial loss: 0.7094995379447937
#
# step: 3884
# discriminator loss: 0.7354661226272583
# adversarial loss: 0.7925509214401245
#
# step: 3889
# discriminator loss: 0.6941553354263306
# adversarial loss: 0.7501078844070435
#
# step: 3894
# discriminator loss: 0.7012092471122742
# adversarial loss: 0.7375612854957581
#
# step: 3899
# discriminator loss: 0.7065121531486511
# adversarial loss: 0.7856915593147278
#
# step: 3904
# discriminator loss: 0.6567045450210571
# adversarial loss: 1.688962697982788
#
# step: 3909
# discriminator loss: 0.6639641523361206
# adversarial loss: 0.7836883068084717
#
# step: 3914
# discriminator loss: 0.7036392688751221
# adversarial loss: 0.8445615768432617
#
# step: 3919
# discriminator loss: 0.7026421427726746
# adversarial loss: 0.738165020942688
#
# step: 3924
# discriminator loss: 0.7143579721450806
# adversarial loss: 0.7345263361930847
#
# step: 3929
# discriminator loss: 0.7435697317123413
# adversarial loss: 0.7954699993133545
#
# step: 3934
# discriminator loss: 0.6952265501022339
# adversarial loss: 0.6238970756530762
#
# step: 3939
# discriminator loss: 0.6934670805931091
# adversarial loss: 0.7006871700286865
#
# step: 3944
# discriminator loss: 0.6934517621994019
# adversarial loss: 0.7081478834152222
#
# step: 3949
# discriminator loss: 0.7032405734062195
# adversarial loss: 0.7498073577880859
#
# step: 3954
# discriminator loss: 0.6812704801559448
# adversarial loss: 0.7278872728347778
#
# step: 3959
# discriminator loss: 0.6879066824913025
# adversarial loss: 0.727369487285614
#
# step: 3964
# discriminator loss: 0.7375242114067078
# adversarial loss: 0.799892008304596
#
# step: 3969
# discriminator loss: 0.6786285638809204
# adversarial loss: 0.7658810615539551
#
# step: 3974
# discriminator loss: 0.6867493987083435
# adversarial loss: 0.7769057154655457
#
# step: 3979
# discriminator loss: 0.7070692777633667
# adversarial loss: 0.7338458895683289
#
# step: 3984
# discriminator loss: 0.6960138082504272
# adversarial loss: 0.7325510382652283
#
# step: 3989
# discriminator loss: 0.6883134841918945
# adversarial loss: 0.7112406492233276
#
# step: 3994
# discriminator loss: 0.7052041888237
# adversarial loss: 0.7215325832366943
#
# step: 3999
# discriminator loss: 0.7208017110824585
# adversarial loss: 0.7572267651557922
#
# step: 4004
# discriminator loss: 0.7158085703849792
# adversarial loss: 0.7690516710281372
#
# step: 4009
# discriminator loss: 0.6971495747566223
# adversarial loss: 0.72166907787323
#
# step: 4014
# discriminator loss: 0.7111228704452515
# adversarial loss: 0.7565760612487793
#
# step: 4019
# discriminator loss: 0.704948902130127
# adversarial loss: 0.743252158164978
#
# step: 4024
# discriminator loss: 0.6950784921646118
# adversarial loss: 0.760721743106842
#
# step: 4029
# discriminator loss: 0.6975822448730469
# adversarial loss: 0.7247848510742188
#
# step: 4034
# discriminator loss: 0.7005870938301086
# adversarial loss: 0.7386355400085449
#
# step: 4039
# discriminator loss: 0.7468324303627014
# adversarial loss: 0.7057821750640869
#
# step: 4044
# discriminator loss: 0.7010040283203125
# adversarial loss: 0.7490151524543762
#
# step: 4049
# discriminator loss: 0.6980947852134705
# adversarial loss: 0.7220383882522583
#
# step: 4054
# discriminator loss: 0.6869231462478638
# adversarial loss: 0.7226500511169434
#
# step: 4059
# discriminator loss: 0.6867210268974304
# adversarial loss: 0.7368146181106567
#
# step: 4064
# discriminator loss: 0.7010506391525269
# adversarial loss: 0.7645991444587708
#
# step: 4069
# discriminator loss: 0.6803872585296631
# adversarial loss: 0.7375596165657043
#
# step: 4074
# discriminator loss: 0.7056925892829895
# adversarial loss: 0.7460131645202637
#
# step: 4079
# discriminator loss: 0.708269476890564
# adversarial loss: 0.7459310293197632
#
# step: 4084
# discriminator loss: 0.6919227242469788
# adversarial loss: 0.7431048154830933
#
# step: 4089
# discriminator loss: 0.6905005574226379
# adversarial loss: 0.7451440095901489
#
# step: 4094
# discriminator loss: 0.7028316259384155
# adversarial loss: 0.7679952383041382
#
# step: 4099
# discriminator loss: 0.6937900185585022
# adversarial loss: 0.7066652774810791
#
# step: 4104
# discriminator loss: 0.6990200281143188
# adversarial loss: 0.7751089930534363
#
# step: 4109
# discriminator loss: 0.702862560749054
# adversarial loss: 0.7637525796890259
#
# step: 4114
# discriminator loss: 0.6974137425422668
# adversarial loss: 0.7333704829216003
#
# step: 4119
# discriminator loss: 0.6922250390052795
# adversarial loss: 0.7394846677780151
#
# step: 4124
# discriminator loss: 0.6956304311752319
# adversarial loss: 0.7413161396980286
#
# step: 4129
# discriminator loss: 0.6933426260948181
# adversarial loss: 0.7204248309135437
#
# step: 4134
# discriminator loss: 1.2762982845306396
# adversarial loss: 0.7268338203430176
#
# step: 4139
# discriminator loss: 0.7003312110900879
# adversarial loss: 0.7059836387634277
#
# step: 4144
# discriminator loss: 0.684813380241394
# adversarial loss: 0.731239914894104
#
# step: 4149
# discriminator loss: 0.680426299571991
# adversarial loss: 0.7408415079116821
#
# step: 4154
# discriminator loss: 0.6981777548789978
# adversarial loss: 0.7616691589355469
#
# step: 4159
# discriminator loss: 0.6905895471572876
# adversarial loss: 0.82269686460495
#
# step: 4164
# discriminator loss: 0.7095636129379272
# adversarial loss: 0.7345151901245117
#
# step: 4169
# discriminator loss: 0.718989372253418
# adversarial loss: 0.7778396606445312
#
# step: 4174
# discriminator loss: 0.6802781224250793
# adversarial loss: 0.7459937334060669
#
# step: 4179
# discriminator loss: 0.7073267102241516
# adversarial loss: 0.7378259897232056
#
# step: 4184
# discriminator loss: 0.6897490620613098
# adversarial loss: 0.725496768951416
#
# step: 4189
# discriminator loss: 0.6946463584899902
# adversarial loss: 0.754015326499939
#
# step: 4194
# discriminator loss: 0.6983885169029236
# adversarial loss: 0.726006805896759
#
# step: 4199
# discriminator loss: 0.7036886215209961
# adversarial loss: 0.7282971143722534
#
# step: 4204
# discriminator loss: 0.6896452307701111
# adversarial loss: 0.7351154088973999
#
# step: 4209
# discriminator loss: 0.6928884387016296
# adversarial loss: 0.5976008772850037
#
# step: 4214
# discriminator loss: 0.6961157321929932
# adversarial loss: 0.7302375435829163
#
# step: 4219
# discriminator loss: 0.6968516111373901
# adversarial loss: 0.7276507616043091
#
# step: 4224
# discriminator loss: 0.6948599219322205
# adversarial loss: 0.7238089442253113
#
# step: 4229
# discriminator loss: 0.7152643203735352
# adversarial loss: 0.748043417930603
#
# step: 4234
# discriminator loss: 0.6943262815475464
# adversarial loss: 0.7830606698989868
#
# step: 4239
# discriminator loss: 0.7735264897346497
# adversarial loss: 0.7677571177482605
#
# step: 4244
# discriminator loss: 0.6724506616592407
# adversarial loss: 0.7694944739341736
#
# step: 4249
# discriminator loss: 0.6875542402267456
# adversarial loss: 0.7481101155281067
#
# step: 4254
# discriminator loss: 0.6895407438278198
# adversarial loss: 0.8109857439994812
#
# step: 4259
# discriminator loss: 0.6951767206192017
# adversarial loss: 0.7146936058998108
#
# step: 4264
# discriminator loss: 0.6945272088050842
# adversarial loss: 0.72608882188797
#
# step: 4269
# discriminator loss: 0.7364052534103394
# adversarial loss: 0.6960212588310242
#
# step: 4274
# discriminator loss: 0.7142003774642944
# adversarial loss: 0.7341322898864746
#
# step: 4279
# discriminator loss: 0.6896170973777771
# adversarial loss: 0.7455840706825256
#
# step: 4284
# discriminator loss: 0.704893946647644
# adversarial loss: 0.7254985570907593
#
# step: 4289
# discriminator loss: 0.7002479434013367
# adversarial loss: 0.7577868700027466
#
# step: 4294
# discriminator loss: 0.6803895235061646
# adversarial loss: 0.7453115582466125
#
# step: 4299
# discriminator loss: 0.6868568658828735
# adversarial loss: 0.7543741464614868
#
# step: 4304
# discriminator loss: 0.686210036277771
# adversarial loss: 0.80946284532547
#
# step: 4309
# discriminator loss: 0.6891294717788696
# adversarial loss: 0.7778288125991821
#
# step: 4314
# discriminator loss: 0.7018721103668213
# adversarial loss: 0.7650291323661804
#
# step: 4319
# discriminator loss: 0.684170126914978
# adversarial loss: 0.7636483311653137
#
# step: 4324
# discriminator loss: 0.7014911770820618
# adversarial loss: 0.7515155673027039
#
# step: 4329
# discriminator loss: 0.6839105486869812
# adversarial loss: 0.5466219782829285
#
# step: 4334
# discriminator loss: 0.6953724026679993
# adversarial loss: 0.7429510354995728
#
# step: 4339
# discriminator loss: 0.7067040205001831
# adversarial loss: 0.7297720909118652
#
# step: 4344
# discriminator loss: 0.6980994343757629
# adversarial loss: 0.7425867915153503
#
# step: 4349
# discriminator loss: 0.6968746185302734
# adversarial loss: 0.8299559354782104
#
# step: 4354
# discriminator loss: 0.6923017501831055
# adversarial loss: 0.7459582090377808
#
# step: 4359
# discriminator loss: 0.6903840899467468
# adversarial loss: 0.751589298248291
#
# step: 4364
# discriminator loss: 0.6895076036453247
# adversarial loss: 0.729982852935791
#
# step: 4369
# discriminator loss: 0.6966193318367004
# adversarial loss: 0.7275711894035339
#
# step: 4374
# discriminator loss: 0.6788150072097778
# adversarial loss: 0.8152405023574829
#
# step: 4379
# discriminator loss: 0.6721664071083069
# adversarial loss: 0.6660147309303284
#
# step: 4384
# discriminator loss: 0.7009543776512146
# adversarial loss: 0.7787346839904785
#
# step: 4389
# discriminator loss: 0.6953781843185425
# adversarial loss: 0.8006202578544617
#
# step: 4394
# discriminator loss: 0.9949871301651001
# adversarial loss: 0.8058544397354126
#
# step: 4399
# discriminator loss: 0.6893668174743652
# adversarial loss: 0.811630368232727
#
# step: 4404
# discriminator loss: 0.701492428779602
# adversarial loss: 0.7220777273178101
#
# step: 4409
# discriminator loss: 0.6925843358039856
# adversarial loss: 0.7341299653053284
#
# step: 4414
# discriminator loss: 0.6873428821563721
# adversarial loss: 0.769484281539917
#
# step: 4419
# discriminator loss: 0.6919659376144409
# adversarial loss: 0.7382366061210632
#
# step: 4424
# discriminator loss: 0.6927582025527954
# adversarial loss: 0.7512572407722473
#
# step: 4429
# discriminator loss: 0.6916447281837463
# adversarial loss: 0.7591989636421204
#
# step: 4434
# discriminator loss: 0.6889461278915405
# adversarial loss: 0.6870523691177368
#
# step: 4439
# discriminator loss: 0.6786066293716431
# adversarial loss: 0.705962061882019
#
# step: 4444
# discriminator loss: 0.679581880569458
# adversarial loss: 0.7599783539772034
#
# step: 4449
# discriminator loss: 0.6918150186538696
# adversarial loss: 0.8024916648864746
#
# step: 4454
# discriminator loss: 0.7032735347747803
# adversarial loss: 0.7610545754432678
#
# step: 4459
# discriminator loss: 0.7166637182235718
# adversarial loss: 0.794708788394928
#
# step: 4464
# discriminator loss: 0.6850636601448059
# adversarial loss: 0.7863979935646057
#
# step: 4469
# discriminator loss: 0.6879550218582153
# adversarial loss: 2.2573578357696533
#
# step: 4474
# discriminator loss: 0.7185567617416382
# adversarial loss: 0.7949935793876648
#
# step: 4479
# discriminator loss: 0.683296799659729
# adversarial loss: 0.7680101990699768
#
# step: 4484
# discriminator loss: 0.7062417268753052
# adversarial loss: 0.7814715504646301
#
# step: 4489
# discriminator loss: 0.7158037424087524
# adversarial loss: 0.7297431230545044
#
# step: 4494
# discriminator loss: 0.7051895260810852
# adversarial loss: 0.7607952952384949
#
# step: 4499
# discriminator loss: 0.8137508630752563
# adversarial loss: 0.7649092674255371
#
# step: 4504
# discriminator loss: 0.6986585855484009
# adversarial loss: 0.7597355842590332
#
# step: 4509
# discriminator loss: 0.7030342221260071
# adversarial loss: 0.7923402786254883
#
# step: 4514
# discriminator loss: 0.6891880631446838
# adversarial loss: 0.7591997385025024
#
# step: 4519
# discriminator loss: 0.694668710231781
# adversarial loss: 0.7456757426261902
#
# step: 4524
# discriminator loss: 0.6983340382575989
# adversarial loss: 0.6727901697158813
#
# step: 4529
# discriminator loss: 0.679304301738739
# adversarial loss: 0.8278921246528625
#
# step: 4534
# discriminator loss: 0.7003428339958191
# adversarial loss: 0.7024407386779785
#
# step: 4539
# discriminator loss: 0.6864933371543884
# adversarial loss: 0.7363201379776001
#
# step: 4544
# discriminator loss: 0.7138035893440247
# adversarial loss: 0.7194835543632507
#
# step: 4549
# discriminator loss: 0.6977771520614624
# adversarial loss: 0.7443001866340637
#
# step: 4554
# discriminator loss: 0.6901582479476929
# adversarial loss: 0.7529193162918091
#
# step: 4559
# discriminator loss: 0.6832286715507507
# adversarial loss: 0.7749152779579163
#
# step: 4564
# discriminator loss: 0.6890986561775208
# adversarial loss: 0.7932172417640686
#
# step: 4569
# discriminator loss: 0.6895910501480103
# adversarial loss: 0.778084397315979
#
# step: 4574
# discriminator loss: 0.7128962278366089
# adversarial loss: 0.7579746246337891
#
# step: 4579
# discriminator loss: 0.6909738779067993
# adversarial loss: 0.74432373046875
#
# step: 4584
# discriminator loss: 0.6761897206306458
# adversarial loss: 0.7807788848876953
#
# step: 4589
# discriminator loss: 0.7051391005516052
# adversarial loss: 0.7438942193984985
#
# step: 4594
# discriminator loss: 0.6864500045776367
# adversarial loss: 0.7670078873634338
#
# step: 4599
# discriminator loss: 0.7023480534553528
# adversarial loss: 0.7191861867904663
#
# step: 4604
# discriminator loss: 0.6927844285964966
# adversarial loss: 0.7172737121582031
#
# step: 4609
# discriminator loss: 0.7119072675704956
# adversarial loss: 0.8257437944412231
#
# step: 4614
# discriminator loss: 0.691184401512146
# adversarial loss: 0.776593804359436
#
# step: 4619
# discriminator loss: 0.6919695138931274
# adversarial loss: 0.8517942428588867
#
# step: 4624
# discriminator loss: 0.6962937712669373
# adversarial loss: 0.8784621953964233
#
# step: 4629
# discriminator loss: 0.698621928691864
# adversarial loss: 0.7407243847846985
#
# step: 4634
# discriminator loss: 0.6838831305503845
# adversarial loss: 0.7580678462982178
#
# step: 4639
# discriminator loss: 0.6953566670417786
# adversarial loss: 0.7654897570610046
#
# step: 4644
# discriminator loss: 0.6953569650650024
# adversarial loss: 0.7241024374961853
#
# step: 4649
# discriminator loss: 0.6912015080451965
# adversarial loss: 0.8643152117729187
#
# step: 4654
# discriminator loss: 0.7016207575798035
# adversarial loss: 0.7125017046928406
#
# step: 4659
# discriminator loss: 0.7094233632087708
# adversarial loss: 0.7250515222549438
#
# step: 4664
# discriminator loss: 0.6869853734970093
# adversarial loss: 0.7165175676345825
#
# step: 4669
# discriminator loss: 0.6889731287956238
# adversarial loss: 0.738659679889679
#
# step: 4674
# discriminator loss: 0.7318897247314453
# adversarial loss: 0.7433401346206665
#
# step: 4679
# discriminator loss: 0.6879230737686157
# adversarial loss: 0.7488285899162292
#
# step: 4684
# discriminator loss: 0.6892141699790955
# adversarial loss: 0.7173964381217957
#
# step: 4689
# discriminator loss: 0.6962812542915344
# adversarial loss: 0.9336951971054077
#
# step: 4694
# discriminator loss: 0.6844578981399536
# adversarial loss: 1.098961591720581
#
# step: 4699
# discriminator loss: 0.6912772059440613
# adversarial loss: 0.7348676919937134
#
# step: 4704
# discriminator loss: 0.6933804750442505
# adversarial loss: 0.7163666486740112
#
# step: 4709
# discriminator loss: 0.7081692814826965
# adversarial loss: 0.719232439994812
#
# step: 4714
# discriminator loss: 0.6788278818130493
# adversarial loss: 0.7790017127990723
#
# step: 4719
# discriminator loss: 0.6811714768409729
# adversarial loss: 0.787792980670929
#
# step: 4724
# discriminator loss: 0.7016264796257019
# adversarial loss: 0.7076054215431213
#
# step: 4729
# discriminator loss: 0.6946074366569519
# adversarial loss: 0.7848404049873352
#
# step: 4734
# discriminator loss: 0.6922608017921448
# adversarial loss: 0.7532392740249634
#
# step: 4739
# discriminator loss: 0.6960951089859009
# adversarial loss: 0.7875972390174866
#
# step: 4744
# discriminator loss: 0.6872660517692566
# adversarial loss: 0.7684210538864136
#
# step: 4749
# discriminator loss: 0.6951694488525391
# adversarial loss: 0.7327160239219666
#
# step: 4754
# discriminator loss: 0.6897082328796387
# adversarial loss: 0.7659855484962463
#
# step: 4759
# discriminator loss: 0.6969896554946899
# adversarial loss: 0.7282103300094604
#
# step: 4764
# discriminator loss: 0.7030087113380432
# adversarial loss: 0.7564343214035034
#
# step: 4769
# discriminator loss: 0.770145058631897
# adversarial loss: 0.7615880370140076
#
# step: 4774
# discriminator loss: 0.6850855946540833
# adversarial loss: 0.679834246635437
#
# step: 4779
# discriminator loss: 0.67503821849823
# adversarial loss: 0.7795771360397339
#
# step: 4784
# discriminator loss: 0.7052133679389954
# adversarial loss: 0.7441862225532532
#
# step: 4789
# discriminator loss: 0.6887136697769165
# adversarial loss: 0.7442687153816223
#
# step: 4794
# discriminator loss: 0.6975840330123901
# adversarial loss: 0.7655514478683472
#
# step: 4799
# discriminator loss: 0.686830997467041
# adversarial loss: 0.7364663481712341
#
# step: 4804
# discriminator loss: 0.6900492906570435
# adversarial loss: 0.7632458806037903
#
# step: 4809
# discriminator loss: 0.7024780511856079
# adversarial loss: 0.737809419631958
#
# step: 4814
# discriminator loss: 0.7062456607818604
# adversarial loss: 0.7437837719917297
#
# step: 4819
# discriminator loss: 0.6952310800552368
# adversarial loss: 0.7148966789245605
#
# step: 4824
# discriminator loss: 0.6933154463768005
# adversarial loss: 0.7517443895339966
#
# step: 4829
# discriminator loss: 0.6932694315910339
# adversarial loss: 0.7520302534103394
#
# step: 4834
# discriminator loss: 0.6922818422317505
# adversarial loss: 1.0558252334594727
#
# step: 4839
# discriminator loss: 0.703752875328064
# adversarial loss: 0.7356563806533813
#
# step: 4844
# discriminator loss: 0.6922355890274048
# adversarial loss: 0.7574911117553711
#
# step: 4849
# discriminator loss: 0.6981405019760132
# adversarial loss: 0.787964940071106
#
# step: 4854
# discriminator loss: 0.6963987946510315
# adversarial loss: 0.7485014200210571
#
# step: 4859
# discriminator loss: 0.7012398838996887
# adversarial loss: 0.7468000650405884
#
# step: 4864
# discriminator loss: 0.7064825892448425
# adversarial loss: 0.7508710622787476
#
# step: 4869
# discriminator loss: 0.6974211931228638
# adversarial loss: 0.7616544365882874
#
# step: 4874
# discriminator loss: 0.6905445456504822
# adversarial loss: 0.7958108186721802
#
# step: 4879
# discriminator loss: 0.7119656801223755
# adversarial loss: 0.7462034225463867
#
# step: 4884
# discriminator loss: 0.6915552020072937
# adversarial loss: 0.7712444067001343
#
# step: 4889
# discriminator loss: 0.707362949848175
# adversarial loss: 0.7357967495918274
#
# step: 4894
# discriminator loss: 0.6973885297775269
# adversarial loss: 0.7398471236228943
#
# step: 4899
# discriminator loss: 0.7067675590515137
# adversarial loss: 0.9809350967407227
#
# step: 4904
# discriminator loss: 0.6909579634666443
# adversarial loss: 0.7356864809989929
#
# step: 4909
# discriminator loss: 0.688994288444519
# adversarial loss: 0.747107744216919
#
# step: 4914
# discriminator loss: 0.6921537518501282
# adversarial loss: 0.716162383556366
#
# step: 4919
# discriminator loss: 0.6962530016899109
# adversarial loss: 0.7737349271774292
#
# step: 4924
# discriminator loss: 0.6943984031677246
# adversarial loss: 0.7464919090270996
#
# step: 4929
# discriminator loss: 0.6968268156051636
# adversarial loss: 0.7485938668251038
#
# step: 4934
# discriminator loss: 0.6807141304016113
# adversarial loss: 0.6812933683395386
#
# step: 4939
# discriminator loss: 0.6934946775436401
# adversarial loss: 0.7416778802871704
#
# step: 4944
# discriminator loss: 0.6979748010635376
# adversarial loss: 0.7656041383743286
#
# step: 4949
# discriminator loss: 0.7042171359062195
# adversarial loss: 0.7484461665153503
#
# step: 4954
# discriminator loss: 0.6938468217849731
# adversarial loss: 0.7485156655311584
#
# step: 4959
# discriminator loss: 0.6983758211135864
# adversarial loss: 0.7254925966262817
#
# step: 4964
# discriminator loss: 0.6994523406028748
# adversarial loss: 0.7841434478759766
#
# step: 4969
# discriminator loss: 0.6787468791007996
# adversarial loss: 0.7837327122688293
#
# step: 4974
# discriminator loss: 0.6882836222648621
# adversarial loss: 0.7237493395805359
#
# step: 4979
# discriminator loss: 0.7000209093093872
# adversarial loss: 0.7635360956192017
#
# step: 4984
# discriminator loss: 0.6844877600669861
# adversarial loss: 0.7410535216331482
#
# step: 4989
# discriminator loss: 0.6944363713264465
# adversarial loss: 0.742919921875
#
# step: 4994
# discriminator loss: 0.7002884745597839
# adversarial loss: 0.7376872897148132
#
# step: 4999
# discriminator loss: 0.7020518183708191
# adversarial loss: 0.7411185503005981
#
# step: 5004
# discriminator loss: 0.6944900751113892
# adversarial loss: 0.8003334999084473
#
# step: 5009
# discriminator loss: 0.6909211277961731
# adversarial loss: 0.7629032135009766
#
# step: 5014
# discriminator loss: 0.6958920359611511
# adversarial loss: 0.726793646812439
#
# step: 5019
# discriminator loss: 0.714262843132019
# adversarial loss: 0.7023729085922241
#
# step: 5024
# discriminator loss: 0.7122873067855835
# adversarial loss: 0.6948612928390503
#
# step: 5029
# discriminator loss: 0.7082731127738953
# adversarial loss: 0.775172233581543
#
# step: 5034
# discriminator loss: 0.7001681327819824
# adversarial loss: 0.755363941192627
#
# step: 5039
# discriminator loss: 0.7230839729309082
# adversarial loss: 0.7604323625564575
#
# step: 5044
# discriminator loss: 0.6975283026695251
# adversarial loss: 0.7512443661689758
#
# step: 5049
# discriminator loss: 0.7494046688079834
# adversarial loss: 0.7985879182815552
#
# step: 5054
# discriminator loss: 0.702364444732666
# adversarial loss: 0.773414134979248
#
# step: 5059
# discriminator loss: 0.7013726234436035
# adversarial loss: 0.7707276344299316
#
# step: 5064
# discriminator loss: 0.6968611478805542
# adversarial loss: 0.7362527251243591
#
# step: 5069
# discriminator loss: 0.6894538402557373
# adversarial loss: 0.7820010185241699
#
# step: 5074
# discriminator loss: 0.6898195743560791
# adversarial loss: 0.7248393297195435
#
# step: 5079
# discriminator loss: 0.6953980326652527
# adversarial loss: 0.7371944189071655
#
# step: 5084
# discriminator loss: 0.6929084658622742
# adversarial loss: 0.7432358264923096
#
# step: 5089
# discriminator loss: 0.698989987373352
# adversarial loss: 0.8002548217773438
#
# step: 5094
# discriminator loss: 0.7118980288505554
# adversarial loss: 0.7793046236038208
#
# step: 5099
# discriminator loss: 0.6866141557693481
# adversarial loss: 0.7363774180412292
#
# step: 5104
# discriminator loss: 0.6981322765350342
# adversarial loss: 0.7412382364273071
#
# step: 5109
# discriminator loss: 0.6912496089935303
# adversarial loss: 0.7486701011657715
#
# step: 5114
# discriminator loss: 0.6963523030281067
# adversarial loss: 0.7609677314758301
#
# step: 5119
# discriminator loss: 0.6983726620674133
# adversarial loss: 0.7324908375740051
#
# step: 5124
# discriminator loss: 0.7048123478889465
# adversarial loss: 0.7415276765823364
#
# step: 5129
# discriminator loss: 0.69228595495224
# adversarial loss: 0.7445155382156372
#
# step: 5134
# discriminator loss: 0.7005017995834351
# adversarial loss: 0.8231420516967773
#
# step: 5139
# discriminator loss: 0.6916359663009644
# adversarial loss: 0.9205109477043152
#
# step: 5144
# discriminator loss: 0.6880074739456177
# adversarial loss: 0.7547156810760498
#
# step: 5149
# discriminator loss: 0.6873884201049805
# adversarial loss: 0.7729279398918152
#
# step: 5154
# discriminator loss: 0.6952517628669739
# adversarial loss: 0.7524226307868958
#
# step: 5159
# discriminator loss: 0.7002471089363098
# adversarial loss: 0.7533668875694275
#
# step: 5164
# discriminator loss: 0.6894016265869141
# adversarial loss: 0.7478954195976257
#
# step: 5169
# discriminator loss: 0.7045605182647705
# adversarial loss: 1.0862537622451782
#
# step: 5174
# discriminator loss: 0.7107821702957153
# adversarial loss: 0.802315890789032
#
# step: 5179
# discriminator loss: 0.6979001760482788
# adversarial loss: 0.7805811166763306
#
# step: 5184
# discriminator loss: 0.6964761018753052
# adversarial loss: 0.7316787838935852
#
# step: 5189
# discriminator loss: 0.7003033757209778
# adversarial loss: 0.8011535406112671
#
# step: 5194
# discriminator loss: 0.6951845288276672
# adversarial loss: 0.7904881834983826
#
# step: 5199
# discriminator loss: 0.7095313668251038
# adversarial loss: 0.7248345613479614
#
# step: 5204
# discriminator loss: 0.7008251547813416
# adversarial loss: 0.7483538389205933
#
# step: 5209
# discriminator loss: 0.6878180503845215
# adversarial loss: 0.7302936315536499
#
# step: 5214
# discriminator loss: 0.6959928274154663
# adversarial loss: 0.7860509157180786
#
# step: 5219
# discriminator loss: 0.7004787921905518
# adversarial loss: 0.761566162109375
#
# step: 5224
# discriminator loss: 0.6761768460273743
# adversarial loss: 0.7293118238449097
#
# step: 5229
# discriminator loss: 0.7168726921081543
# adversarial loss: 0.7299337387084961
#
# step: 5234
# discriminator loss: 0.6848099231719971
# adversarial loss: 0.8142820596694946
#
# step: 5239
# discriminator loss: 0.6887006759643555
# adversarial loss: 0.7445061206817627
#
# step: 5244
# discriminator loss: 0.690838098526001
# adversarial loss: 0.7939740419387817
#
# step: 5249
# discriminator loss: 0.6966557502746582
# adversarial loss: 0.7872412800788879
#
# step: 5254
# discriminator loss: 0.6859759092330933
# adversarial loss: 0.7616065144538879
#
# step: 5259
# discriminator loss: 0.7012292146682739
# adversarial loss: 0.7479910850524902
#
# step: 5264
# discriminator loss: 0.6801403164863586
# adversarial loss: 0.7590800523757935
#
# step: 5269
# discriminator loss: 0.7134512662887573
# adversarial loss: 0.7303646802902222
#
# step: 5274
# discriminator loss: 0.6914849877357483
# adversarial loss: 0.6687039136886597
#
# step: 5279
# discriminator loss: 0.6930146217346191
# adversarial loss: 0.7957368493080139
#
# step: 5284
# discriminator loss: 0.6890381574630737
# adversarial loss: 0.7589753866195679
#
# step: 5289
# discriminator loss: 0.6856704950332642
# adversarial loss: 0.8112674951553345
#
# step: 5294
# discriminator loss: 0.6583915948867798
# adversarial loss: 1.2222331762313843
#
# step: 5299
# discriminator loss: 0.6991037726402283
# adversarial loss: 0.7911376357078552
#
# step: 5304
# discriminator loss: 0.6922231316566467
# adversarial loss: 0.7507770657539368
#
# step: 5309
# discriminator loss: 0.6673704385757446
# adversarial loss: 0.7152432799339294
#
# step: 5314
# discriminator loss: 0.7052793502807617
# adversarial loss: 0.7631110548973083
#
# step: 5319
# discriminator loss: 0.675122857093811
# adversarial loss: 0.7350372076034546
#
# step: 5324
# discriminator loss: 0.6991426348686218
# adversarial loss: 0.7412821054458618
#
# step: 5329
# discriminator loss: 0.6739708781242371
# adversarial loss: 0.738926112651825
#
# step: 5334
# discriminator loss: 0.6962555050849915
# adversarial loss: 0.733340859413147
#
# step: 5339
# discriminator loss: 0.6971846222877502
# adversarial loss: 0.758428692817688
#
# step: 5344
# discriminator loss: 0.694770336151123
# adversarial loss: 0.7138412594795227
#
# step: 5349
# discriminator loss: 0.690264105796814
# adversarial loss: 0.7653274536132812
#
# step: 5354
# discriminator loss: 0.7306296229362488
# adversarial loss: 0.8374778032302856
#
# step: 5359
# discriminator loss: 0.7024362683296204
# adversarial loss: 0.7395044565200806
#
# step: 5364
# discriminator loss: 0.6901441812515259
# adversarial loss: 0.6968817710876465
#
# step: 5369
# discriminator loss: 0.7027480602264404
# adversarial loss: 0.7440310716629028
#
# step: 5374
# discriminator loss: 0.6950622797012329
# adversarial loss: 0.7539522051811218
#
# step: 5379
# discriminator loss: 0.692902684211731
# adversarial loss: 0.8189558982849121
#
# step: 5384
# discriminator loss: 0.6937152147293091
# adversarial loss: 0.7755735516548157
#
# step: 5389
# discriminator loss: 0.7004400491714478
# adversarial loss: 0.7412341833114624
#
# step: 5394
# discriminator loss: 0.6951057314872742
# adversarial loss: 1.0471858978271484
#
# step: 5399
# discriminator loss: 0.6906062364578247
# adversarial loss: 0.7765600681304932
#
# step: 5404
# discriminator loss: 0.6863971948623657
# adversarial loss: 0.7711507678031921
#
# step: 5409
# discriminator loss: 0.6845442056655884
# adversarial loss: 0.7300914525985718
#
# step: 5414
# discriminator loss: 0.6856479048728943
# adversarial loss: 0.7577440738677979
#
# step: 5419
# discriminator loss: 0.6821490526199341
# adversarial loss: 0.7368998527526855
#
# step: 5424
# discriminator loss: 0.7038019895553589
# adversarial loss: 0.7673673629760742
#
# step: 5429
# discriminator loss: 0.702603280544281
# adversarial loss: 0.7949619293212891
#
# step: 5434
# discriminator loss: 0.7011715769767761
# adversarial loss: 0.7540218830108643
#
# step: 5439
# discriminator loss: 0.6850969195365906
# adversarial loss: 0.7073801755905151
#
# step: 5444
# discriminator loss: 0.6896464228630066
# adversarial loss: 0.7493836283683777
#
# step: 5449
# discriminator loss: 0.698045551776886
# adversarial loss: 0.7335243225097656
#
# step: 5454
# discriminator loss: 0.698206901550293
# adversarial loss: 0.7068044543266296
#
# step: 5459
# discriminator loss: 0.6994173526763916
# adversarial loss: 0.7529634833335876
#
# step: 5464
# discriminator loss: 0.6988388299942017
# adversarial loss: 0.9943652153015137
#
# step: 5469
# discriminator loss: 0.7531757950782776
# adversarial loss: 0.7705527544021606
#
# step: 5474
# discriminator loss: 0.7148391008377075
# adversarial loss: 0.758894681930542
#
# step: 5479
# discriminator loss: 0.6997839212417603
# adversarial loss: 0.74879390001297
#
# step: 5484
# discriminator loss: 0.6934544444084167
# adversarial loss: 0.7430140376091003
#
# step: 5489
# discriminator loss: 0.7018688321113586
# adversarial loss: 0.795035719871521
#
# step: 5494
# discriminator loss: 0.7077999114990234
# adversarial loss: 0.7461000680923462
#
# step: 5499
# discriminator loss: 0.6873665452003479
# adversarial loss: 0.8128126263618469
#
# step: 5504
# discriminator loss: 0.6902138590812683
# adversarial loss: 0.7578381299972534
#
# step: 5509
# discriminator loss: 0.695415198802948
# adversarial loss: 0.7812631726264954
#
# step: 5514
# discriminator loss: 0.6960164308547974
# adversarial loss: 0.7237462997436523
#
# step: 5519
# discriminator loss: 0.688971996307373
# adversarial loss: 0.7510976195335388
#
# step: 5524
# discriminator loss: 0.6946068406105042
# adversarial loss: 0.7815024256706238
#
# step: 5529
# discriminator loss: 0.7047020196914673
# adversarial loss: 0.8560051918029785
#
# step: 5534
# discriminator loss: 0.7143039703369141
# adversarial loss: 0.7927382588386536
#
# step: 5539
# discriminator loss: 0.692671000957489
# adversarial loss: 0.7129483222961426
#
# step: 5544
# discriminator loss: 0.6888284683227539
# adversarial loss: 0.7157838344573975
#
# step: 5549
# discriminator loss: 0.7038066387176514
# adversarial loss: 0.76097571849823
#
# step: 5554
# discriminator loss: 0.6908458471298218
# adversarial loss: 0.7781342267990112
#
# step: 5559
# discriminator loss: 0.7010528445243835
# adversarial loss: 0.7625703811645508
#
# step: 5564
# discriminator loss: 0.7126599550247192
# adversarial loss: 0.7760998010635376
#
# step: 5569
# discriminator loss: 0.6838876605033875
# adversarial loss: 0.7613945007324219
#
# step: 5574
# discriminator loss: 0.6925131678581238
# adversarial loss: 0.6527203321456909
#
# step: 5579
# discriminator loss: 0.6973873972892761
# adversarial loss: 0.7344151735305786
#
# step: 5584
# discriminator loss: 0.6977711915969849
# adversarial loss: 0.7387125492095947
#
# step: 5589
# discriminator loss: 0.691827118396759
# adversarial loss: 0.7789065837860107
#
# step: 5594
# discriminator loss: 0.6893153190612793
# adversarial loss: 0.7598004937171936
#
# step: 5599
# discriminator loss: 0.6858401298522949
# adversarial loss: 0.7526212930679321
#
# step: 5604
# discriminator loss: 0.683275580406189
# adversarial loss: 0.731312096118927
#
# step: 5609
# discriminator loss: 0.6868458390235901
# adversarial loss: 0.7386853098869324
#
# step: 5614
# discriminator loss: 0.6726944446563721
# adversarial loss: 1.3510041236877441
#
# step: 5619
# discriminator loss: 0.7075007557868958
# adversarial loss: 0.7472842931747437
#
# step: 5624
# discriminator loss: 0.8622543215751648
# adversarial loss: 0.7523831725120544
#
# step: 5629
# discriminator loss: 0.6980019807815552
# adversarial loss: 0.8206077814102173
#
# step: 5634
# discriminator loss: 0.6997696161270142
# adversarial loss: 0.7696142792701721
#
# step: 5639
# discriminator loss: 0.6963691711425781
# adversarial loss: 0.7613067030906677
#
# step: 5644
# discriminator loss: 0.6762489080429077
# adversarial loss: 0.7377052903175354
#
# step: 5649
# discriminator loss: 0.6807132363319397
# adversarial loss: 0.772253692150116
#
# step: 5654
# discriminator loss: 0.7028328776359558
# adversarial loss: 0.7396417260169983
#
# step: 5659
# discriminator loss: 0.6905073523521423
# adversarial loss: 0.7556821703910828
#
# step: 5664
# discriminator loss: 0.7172456979751587
# adversarial loss: 0.7417103052139282
#
# step: 5669
# discriminator loss: 0.6924447417259216
# adversarial loss: 0.7496944069862366
#
# step: 5674
# discriminator loss: 0.6988471150398254
# adversarial loss: 0.7447324395179749
#
# step: 5679
# discriminator loss: 0.7011532783508301
# adversarial loss: 0.7163171768188477
#
# step: 5684
# discriminator loss: 0.7001388669013977
# adversarial loss: 0.7549518942832947
#
# step: 5689
# discriminator loss: 0.695912778377533
# adversarial loss: 0.756504237651825
#
# step: 5694
# discriminator loss: 0.6832228899002075
# adversarial loss: 0.7413382530212402
#
# step: 5699
# discriminator loss: 0.6772564053535461
# adversarial loss: 0.7343004941940308
#
# step: 5704
# discriminator loss: 0.7004575133323669
# adversarial loss: 0.7067179679870605
#
# step: 5709
# discriminator loss: 0.6981841325759888
# adversarial loss: 0.7576460838317871
#
# step: 5714
# discriminator loss: 0.7010400891304016
# adversarial loss: 0.7438820004463196
#
# step: 5719
# discriminator loss: 0.6965708136558533
# adversarial loss: 0.7531208395957947
#
# step: 5724
# discriminator loss: 0.719386100769043
# adversarial loss: 0.7505953311920166
#
# step: 5729
# discriminator loss: 0.6903064846992493
# adversarial loss: 0.7825247049331665
#
# step: 5734
# discriminator loss: 0.6928451657295227
# adversarial loss: 0.8408058285713196
#
# step: 5739
# discriminator loss: 0.6845936179161072
# adversarial loss: 0.7774804830551147
#
# step: 5744
# discriminator loss: 0.6909917593002319
# adversarial loss: 0.7575607299804688
#
# step: 5749
# discriminator loss: 0.9470195770263672
# adversarial loss: 0.7288521528244019
#
# step: 5754
# discriminator loss: 0.6943928599357605
# adversarial loss: 0.7915158867835999
#
# step: 5759
# discriminator loss: 0.7012525796890259
# adversarial loss: 0.7998248338699341
#
# step: 5764
# discriminator loss: 0.6959643959999084
# adversarial loss: 0.742405116558075
#
# step: 5769
# discriminator loss: 0.6976367831230164
# adversarial loss: 0.7610434293746948
#
# step: 5774
# discriminator loss: 0.6976872682571411
# adversarial loss: 0.7540611624717712
#
# step: 5779
# discriminator loss: 0.696250855922699
# adversarial loss: 0.7773600816726685
#
# step: 5784
# discriminator loss: 0.6938700675964355
# adversarial loss: 0.7264028787612915
#
# step: 5789
# discriminator loss: 0.726524829864502
# adversarial loss: 0.7830662131309509
#
# step: 5794
# discriminator loss: 0.6952736377716064
# adversarial loss: 0.7272429466247559
#
# step: 5799
# discriminator loss: 0.6920745968818665
# adversarial loss: 0.7661234736442566
#
# step: 5804
# discriminator loss: 0.6896335482597351
# adversarial loss: 0.7432915568351746
#
# step: 5809
# discriminator loss: 0.686966598033905
# adversarial loss: 0.7682186365127563
#
# step: 5814
# discriminator loss: 0.6957155466079712
# adversarial loss: 0.7459639310836792
#
# step: 5819
# discriminator loss: 0.6997407674789429
# adversarial loss: 0.7603839635848999
#
# step: 5824
# discriminator loss: 0.6970440149307251
# adversarial loss: 0.7443011403083801
#
# step: 5829
# discriminator loss: 0.6937018632888794
# adversarial loss: 0.733505129814148
#
# step: 5834
# discriminator loss: 0.6950310468673706
# adversarial loss: 0.7323498725891113
#
# step: 5839
# discriminator loss: 0.6934272050857544
# adversarial loss: 0.7593239545822144
#
# step: 5844
# discriminator loss: 0.7721184492111206
# adversarial loss: 0.7717026472091675
#
# step: 5849
# discriminator loss: 0.6840605139732361
# adversarial loss: 0.7505310773849487
#
# step: 5854
# discriminator loss: 0.7020912170410156
# adversarial loss: 0.7715798020362854
#
# step: 5859
# discriminator loss: 0.6960784792900085
# adversarial loss: 0.7643064260482788
#
# step: 5864
# discriminator loss: 0.6936327219009399
# adversarial loss: 0.7540669441223145
#
# step: 5869
# discriminator loss: 0.6947255730628967
# adversarial loss: 0.7538641691207886
#
# step: 5874
# discriminator loss: 0.6908560991287231
# adversarial loss: 0.8164440989494324
#
# step: 5879
# discriminator loss: 0.6662888526916504
# adversarial loss: 0.564583420753479
#
# step: 5884
# discriminator loss: 0.7169075012207031
# adversarial loss: 0.7793611288070679
#
# step: 5889
# discriminator loss: 0.6987859606742859
# adversarial loss: 0.7728455662727356
#
# step: 5894
# discriminator loss: 0.6913403272628784
# adversarial loss: 0.7001400589942932
#
# step: 5899
# discriminator loss: 0.6959723234176636
# adversarial loss: 0.8037487864494324
#
# step: 5904
# discriminator loss: 0.7079879641532898
# adversarial loss: 0.7600330114364624
#
# step: 5909
# discriminator loss: 0.6943626999855042
# adversarial loss: 0.7413247227668762
#
# step: 5914
# discriminator loss: 0.6914530992507935
# adversarial loss: 0.7280023694038391
#
# step: 5919
# discriminator loss: 0.6949655413627625
# adversarial loss: 0.9647636413574219
#
# step: 5924
# discriminator loss: 0.7047874927520752
# adversarial loss: 0.7208631634712219
#
# step: 5929
# discriminator loss: 0.7051512598991394
# adversarial loss: 0.7094700932502747
#
# step: 5934
# discriminator loss: 0.6975909471511841
# adversarial loss: 0.7465195059776306
#
# step: 5939
# discriminator loss: 0.7656961679458618
# adversarial loss: 0.7353848218917847
#
# step: 5944
# discriminator loss: 0.7078210711479187
# adversarial loss: 0.7623096108436584
#
# step: 5949
# discriminator loss: 0.6826078295707703
# adversarial loss: 0.6214731335639954
#
# step: 5954
# discriminator loss: 0.6953352689743042
# adversarial loss: 0.7240058779716492
#
# step: 5959
# discriminator loss: 0.6964901685714722
# adversarial loss: 0.7199428081512451
#
# step: 5964
# discriminator loss: 0.6843891739845276
# adversarial loss: 0.7861582636833191
#
# step: 5969
# discriminator loss: 0.6926015615463257
# adversarial loss: 0.7544590830802917
#
# step: 5974
# discriminator loss: 0.6813937425613403
# adversarial loss: 0.7575379014015198
#
# step: 5979
# discriminator loss: 0.716063380241394
# adversarial loss: 1.07184636592865
#
# step: 5984
# discriminator loss: 0.686721682548523
# adversarial loss: 0.7902114987373352
#
# step: 5989
# discriminator loss: 0.7065855860710144
# adversarial loss: 0.7660927772521973
#
# step: 5994
# discriminator loss: 0.7066676616668701
# adversarial loss: 0.7733662128448486
#
# step: 5999
# discriminator loss: 0.6868933439254761
# adversarial loss: 0.7664653658866882
#
# step: 6004
# discriminator loss: 0.7263195514678955
# adversarial loss: 0.7662965059280396
#
# step: 6009
# discriminator loss: 0.6871265172958374
# adversarial loss: 0.753535270690918
#
# step: 6014
# discriminator loss: 0.6884249448776245
# adversarial loss: 0.7341550588607788
#
# step: 6019
# discriminator loss: 0.6928139328956604
# adversarial loss: 0.8105050325393677
#
# step: 6024
# discriminator loss: 0.7394163012504578
# adversarial loss: 0.7507551908493042
#
# step: 6029
# discriminator loss: 0.6995271444320679
# adversarial loss: 0.7350581884384155
#
# step: 6034
# discriminator loss: 0.6882200241088867
# adversarial loss: 0.7280946373939514
#
# step: 6039
# discriminator loss: 0.6951454877853394
# adversarial loss: 0.7584162354469299
#
# step: 6044
# discriminator loss: 0.692859947681427
# adversarial loss: 0.8386731147766113
#
# step: 6049
# discriminator loss: 0.7024088501930237
# adversarial loss: 0.6948848962783813
#
# step: 6054
# discriminator loss: 0.6967455148696899
# adversarial loss: 0.7816720008850098
#
# step: 6059
# discriminator loss: 0.6949537396430969
# adversarial loss: 0.8024609684944153
#
# step: 6064
# discriminator loss: 0.7011585235595703
# adversarial loss: 0.734718918800354
#
# step: 6069
# discriminator loss: 0.6946644186973572
# adversarial loss: 0.7506153583526611
#
# step: 6074
# discriminator loss: 0.6951984167098999
# adversarial loss: 0.7713438868522644
#
# step: 6079
# discriminator loss: 0.6871345639228821
# adversarial loss: 0.7271121740341187
#
# step: 6084
# discriminator loss: 0.692703127861023
# adversarial loss: 0.8164809942245483
#
# step: 6089
# discriminator loss: 0.6883496046066284
# adversarial loss: 0.7579431533813477
#
# step: 6094
# discriminator loss: 0.6999152302742004
# adversarial loss: 0.7113291025161743
#
# step: 6099
# discriminator loss: 0.6792706251144409
# adversarial loss: 0.6900937557220459
#
# step: 6104
# discriminator loss: 0.7043906450271606
# adversarial loss: 1.0268181562423706
#
# step: 6109
# discriminator loss: 0.7128084897994995
# adversarial loss: 0.7739297151565552
#
# step: 6114
# discriminator loss: 0.6996117830276489
# adversarial loss: 0.7536490559577942
#
# step: 6119
# discriminator loss: 0.6908173561096191
# adversarial loss: 0.9437251091003418
#
# step: 6124
# discriminator loss: 0.6922363042831421
# adversarial loss: 0.7529670000076294
#
# step: 6129
# discriminator loss: 0.6952654123306274
# adversarial loss: 0.6870957016944885
#
# step: 6134
# discriminator loss: 0.7024577856063843
# adversarial loss: 0.7632761001586914
#
# step: 6139
# discriminator loss: 0.6759220957756042
# adversarial loss: 0.6284897923469543
#
# step: 6144
# discriminator loss: 0.7179387211799622
# adversarial loss: 0.8263227343559265
#
# step: 6149
# discriminator loss: 0.6870587468147278
# adversarial loss: 0.6759427189826965
#
# step: 6154
# discriminator loss: 0.7019915580749512
# adversarial loss: 0.7691236734390259
#
# step: 6159
# discriminator loss: 0.6933009028434753
# adversarial loss: 0.7756257653236389
#
# step: 6164
# discriminator loss: 0.7009987831115723
# adversarial loss: 0.7929583787918091
#
# step: 6169
# discriminator loss: 0.703600287437439
# adversarial loss: 0.7717095613479614
#
# step: 6174
# discriminator loss: 0.6993376016616821
# adversarial loss: 0.738902747631073
#
# step: 6179
# discriminator loss: 0.6954585909843445
# adversarial loss: 0.7420668601989746
#
# step: 6184
# discriminator loss: 0.704952597618103
# adversarial loss: 0.7477223873138428
#
# step: 6189
# discriminator loss: 0.7005801200866699
# adversarial loss: 0.7837300300598145
#
# step: 6194
# discriminator loss: 0.6955026388168335
# adversarial loss: 0.7482132911682129
#
# step: 6199
# discriminator loss: 0.6895110607147217
# adversarial loss: 0.724493145942688
#
# step: 6204
# discriminator loss: 0.6883343458175659
# adversarial loss: 0.6467989683151245
#
# step: 6209
# discriminator loss: 0.7034115791320801
# adversarial loss: 0.7183254957199097
#
# step: 6214
# discriminator loss: 0.6922507286071777
# adversarial loss: 0.8012666702270508
#
# step: 6219
# discriminator loss: 0.693522572517395
# adversarial loss: 0.7333771586418152
#
# step: 6224
# discriminator loss: 0.6805416345596313
# adversarial loss: 0.6565231680870056
#
# step: 6229
# discriminator loss: 0.6866043210029602
# adversarial loss: 0.7485624551773071
#
# step: 6234
# discriminator loss: 0.6969520449638367
# adversarial loss: 0.7565940022468567
#
# step: 6239
# discriminator loss: 0.702448308467865
# adversarial loss: 0.748873233795166
#
# step: 6244
# discriminator loss: 0.7071592211723328
# adversarial loss: 0.7289551496505737
#
# step: 6249
# discriminator loss: 0.6996537446975708
# adversarial loss: 0.7421220541000366
#
# step: 6254
# discriminator loss: 0.6862252950668335
# adversarial loss: 0.7918105125427246
#
# step: 6259
# discriminator loss: 0.6825035810470581
# adversarial loss: 0.7673380970954895
#
# step: 6264
# discriminator loss: 0.7072266340255737
# adversarial loss: 0.7080087065696716
#
# step: 6269
# discriminator loss: 0.6935715675354004
# adversarial loss: 0.7360340356826782
#
# step: 6274
# discriminator loss: 0.6713010668754578
# adversarial loss: 1.9740864038467407
#
# step: 6279
# discriminator loss: 0.6844959855079651
# adversarial loss: 0.7237633466720581
#
# step: 6284
# discriminator loss: 0.6785656213760376
# adversarial loss: 0.7467483282089233
#
# step: 6289
# discriminator loss: 0.6944674849510193
# adversarial loss: 0.7264952659606934
#
# step: 6294
# discriminator loss: 0.6886979341506958
# adversarial loss: 0.804028332233429
#
# step: 6299
# discriminator loss: 0.6935271620750427
# adversarial loss: 0.7139857411384583
#
# step: 6304
# discriminator loss: 0.6824185252189636
# adversarial loss: 0.7742990255355835
#
# step: 6309
# discriminator loss: 0.707222580909729
# adversarial loss: 0.7953340411186218
#
# step: 6314
# discriminator loss: 0.6790963411331177
# adversarial loss: 0.7807794809341431
#
# step: 6319
# discriminator loss: 0.7049530148506165
# adversarial loss: 0.7541247606277466
#
# step: 6324
# discriminator loss: 0.7017735242843628
# adversarial loss: 0.6616801023483276
#
# step: 6329
# discriminator loss: 0.7063860893249512
# adversarial loss: 0.7673678994178772
#
# step: 6334
# discriminator loss: 0.6939502358436584
# adversarial loss: 0.752628743648529
#
# step: 6339
# discriminator loss: 0.6848772168159485
# adversarial loss: 0.7623974084854126
#
# step: 6344
# discriminator loss: 0.6832473874092102
# adversarial loss: 0.752996563911438
#
# step: 6349
# discriminator loss: 0.6851367950439453
# adversarial loss: 1.1509685516357422
#
# step: 6354
# discriminator loss: 0.717211127281189
# adversarial loss: 0.8309692144393921
#
# step: 6359
# discriminator loss: 0.7065707445144653
# adversarial loss: 0.7808597087860107
#
# step: 6364
# discriminator loss: 0.709729015827179
# adversarial loss: 0.7249301671981812
#
# step: 6369
# discriminator loss: 0.6837552189826965
# adversarial loss: 0.7249570488929749
#
# step: 6374
# discriminator loss: 0.6923514604568481
# adversarial loss: 0.7471323013305664
#
# step: 6379
# discriminator loss: 0.69105464220047
# adversarial loss: 0.7652126550674438
#
# step: 6384
# discriminator loss: 0.6987032294273376
# adversarial loss: 0.7636064291000366
#
# step: 6389
# discriminator loss: 0.8695786595344543
# adversarial loss: 0.7966700792312622
#
# step: 6394
# discriminator loss: 0.6942449808120728
# adversarial loss: 0.7409178614616394
#
# step: 6399
# discriminator loss: 0.6924278140068054
# adversarial loss: 0.7391809225082397
#
# step: 6404
# discriminator loss: 0.6821014285087585
# adversarial loss: 0.7648359537124634
#
# step: 6409
# discriminator loss: 0.7034158110618591
# adversarial loss: 0.7517848610877991
#
# step: 6414
# discriminator loss: 0.6971167325973511
# adversarial loss: 0.8562000393867493
#
# step: 6419
# discriminator loss: 0.7036029696464539
# adversarial loss: 0.7645117044448853
#
# step: 6424
# discriminator loss: 0.6939290165901184
# adversarial loss: 0.729020893573761
#
# step: 6429
# discriminator loss: 0.6940422058105469
# adversarial loss: 0.7646939754486084
#
# step: 6434
# discriminator loss: 0.7107793092727661
# adversarial loss: 0.736851692199707
#
# step: 6439
# discriminator loss: 0.6858248710632324
# adversarial loss: 0.8003864288330078
#
# step: 6444
# discriminator loss: 0.6839251518249512
# adversarial loss: 0.796003520488739
#
# step: 6449
# discriminator loss: 0.6929278373718262
# adversarial loss: 0.7711042761802673
#
# step: 6454
# discriminator loss: 0.6985761523246765
# adversarial loss: 0.7503644227981567
#
# step: 6459
# discriminator loss: 0.6985055208206177
# adversarial loss: 0.7419804334640503
#
# step: 6464
# discriminator loss: 0.6856913566589355
# adversarial loss: 0.8012849688529968
#
# step: 6469
# discriminator loss: 0.6896032094955444
# adversarial loss: 0.7670022249221802
#
# step: 6474
# discriminator loss: 0.7498787045478821
# adversarial loss: 0.7575207352638245
#
# step: 6479
# discriminator loss: 0.6882970929145813
# adversarial loss: 0.9037488698959351
#
# step: 6484
# discriminator loss: 0.6895157694816589
# ...
#
# step: 9094
# discriminator loss: 0.7342199087142944
# adversarial loss: 0.9140199422836304
#
# step: 9099
# discriminator loss: 0.7157306671142578
# adversarial loss: 0.729819655418396
#
# step: 9104
# discriminator loss: 0.6854698061943054
# adversarial loss: 0.6685723066329956
#
# step: 9109
# discriminator loss: 0.7040413618087769
# adversarial loss: 0.7781122922897339
#
# step: 9114
# discriminator loss: 0.8137828707695007
# adversarial loss: 1.1082899570465088
#
# step: 9119
# discriminator loss: 0.6969493627548218
# adversarial loss: 0.8073692321777344
#
# step: 9124
# discriminator loss: 0.7065507173538208
# adversarial loss: 0.7726656198501587
#
# step: 9129
# discriminator loss: 0.6904857754707336
# adversarial loss: 0.8294177055358887
#
# step: 9134
# discriminator loss: 0.8279045224189758
# adversarial loss: 0.6587581038475037
#
# step: 9139
# discriminator loss: 0.6956610679626465
# adversarial loss: 0.7729252576828003
#
# step: 9144
# discriminator loss: 0.6608254313468933
# adversarial loss: 0.7839257121086121
#
# step: 9149
# discriminator loss: 0.7383607029914856
# adversarial loss: 0.9465410113334656
#
# step: 9154
# discriminator loss: 0.6792818307876587
# adversarial loss: 0.7961763143539429
#
# step: 9159
# discriminator loss: 0.7225908637046814
# adversarial loss: 0.8618282079696655
#
# step: 9164
# discriminator loss: 0.7006323933601379
# adversarial loss: 0.7684252858161926
#
# step: 9169
# discriminator loss: 0.6981242895126343
# adversarial loss: 0.7515910267829895
#
# step: 9174
# discriminator loss: 0.6817158460617065
# adversarial loss: 0.8277227282524109
#
# step: 9179
# discriminator loss: 0.6800404787063599
# adversarial loss: 0.7978390455245972
#
# step: 9184
# discriminator loss: 0.7272833585739136
# adversarial loss: 0.6684864163398743
#
# step: 9189
# discriminator loss: 0.701238751411438
# adversarial loss: 0.8412590026855469
#
# step: 9194
# discriminator loss: 0.7074400782585144
# adversarial loss: 0.6716799736022949
#
# step: 9199
# discriminator loss: 0.685271680355072
# adversarial loss: 0.9441133737564087
#
# step: 9204
# discriminator loss: 0.6977289319038391
# adversarial loss: 0.7085363864898682
#
# step: 9209
# discriminator loss: 0.7261523008346558
# adversarial loss: 0.7305097579956055
#
# step: 9214
# discriminator loss: 0.6572157740592957
# adversarial loss: 0.9212099313735962
#
# step: 9219
# discriminator loss: 0.6936326026916504
# adversarial loss: 0.8219887018203735
#
# step: 9224
# discriminator loss: 0.7101801037788391
# adversarial loss: 0.7405444383621216
#
# step: 9229
# discriminator loss: 0.6754274368286133
# adversarial loss: 0.7377486228942871
#
# step: 9234
# discriminator loss: 0.6654216647148132
# adversarial loss: 0.95819091796875
#
# step: 9239
# discriminator loss: 0.6773823499679565
# adversarial loss: 0.7745480537414551
#
# step: 9244
# discriminator loss: 0.6672704815864563
# adversarial loss: 0.8196823000907898
#
# step: 9249
# discriminator loss: 0.6938139200210571
# adversarial loss: 0.9781819581985474
#
# step: 9254
# discriminator loss: 0.6429610848426819
# adversarial loss: 0.7419408559799194
#
# step: 9259
# discriminator loss: 0.6872988343238831
# adversarial loss: 0.8424959182739258
#
# step: 9264
# discriminator loss: 0.6998780369758606
# adversarial loss: 0.7396624088287354
#
# step: 9269
# discriminator loss: 0.7089582681655884
# adversarial loss: 0.7863831520080566
#
# step: 9274
# discriminator loss: 0.7352371215820312
# adversarial loss: 0.7618765234947205
#
# step: 9279
# discriminator loss: 0.6716773509979248
# adversarial loss: 0.7465245723724365
#
# step: 9284
# discriminator loss: 0.6785321235656738
# adversarial loss: 0.8566485643386841
#
# step: 9289
# discriminator loss: 0.6939058303833008
# adversarial loss: 0.7630130052566528
#
# step: 9294
# discriminator loss: 0.6494277715682983
# adversarial loss: 0.8486841917037964
#
# step: 9299
# discriminator loss: 0.6786215901374817
# adversarial loss: 0.8029200434684753
#
# step: 9304
# discriminator loss: 0.6911547780036926
# adversarial loss: 0.7259310483932495
#
# step: 9309
# discriminator loss: 0.6863135099411011
# adversarial loss: 0.8078077435493469
#
# step: 9314
# discriminator loss: 0.6885074377059937
# adversarial loss: 0.820665717124939
#
# step: 9319
# discriminator loss: 0.6734417080879211
# adversarial loss: 1.1026456356048584
#
# step: 9324
# discriminator loss: 0.7179956436157227
# adversarial loss: 0.7446225881576538
#
# step: 9329
# discriminator loss: 0.6671962738037109
# adversarial loss: 0.25636014342308044
#
# step: 9334
# discriminator loss: 0.6967064142227173
# adversarial loss: 0.8348770141601562
#
# step: 9339
# discriminator loss: 0.6674168705940247
# adversarial loss: 0.9331600069999695
#
# step: 9344
# discriminator loss: 0.6934916973114014
# adversarial loss: 0.7712348103523254
#
# step: 9349
# discriminator loss: 0.7219566106796265
# adversarial loss: 0.9484955072402954
#
# step: 9354
# discriminator loss: 0.6852903962135315
# adversarial loss: 0.7819538712501526
#
# step: 9359
# discriminator loss: 0.6538251042366028
# adversarial loss: 0.8459998965263367
#
# step: 9364
# discriminator loss: 0.6821852922439575
# adversarial loss: 0.8199648857116699
#
# step: 9369
# discriminator loss: 0.666972279548645
# adversarial loss: 1.0101317167282104
#
# step: 9374
# discriminator loss: 0.7991610765457153
# adversarial loss: 1.8412389755249023
#
# step: 9379
# discriminator loss: 0.6536985635757446
# adversarial loss: 0.9579101800918579
#
# step: 9384
# discriminator loss: 0.7456094622612
# adversarial loss: 0.8302747011184692
#
# step: 9389
# discriminator loss: 0.7205089330673218
# adversarial loss: 0.9301335215568542
#
# step: 9394
# discriminator loss: 0.6811099648475647
# adversarial loss: 0.7821585536003113
#
# step: 9399
# discriminator loss: 0.670720636844635
# adversarial loss: 0.6016134023666382
#
# step: 9404
# discriminator loss: 0.6845605373382568
# adversarial loss: 0.8305667042732239
#
# step: 9409
# discriminator loss: 0.6501086950302124
# adversarial loss: 0.785507082939148
#
# step: 9414
# discriminator loss: 0.653205931186676
# adversarial loss: 0.6440969705581665
#
# step: 9419
# discriminator loss: 0.7425346374511719
# adversarial loss: 0.7997539639472961
#
# step: 9424
# discriminator loss: 0.6725370287895203
# adversarial loss: 0.8039776682853699
#
# step: 9429
# discriminator loss: 0.6563413739204407
# adversarial loss: 0.9486697316169739
#
# step: 9434
# discriminator loss: 0.738740086555481
# adversarial loss: 0.8242868185043335
#
# step: 9439
# discriminator loss: 0.7105018496513367
# adversarial loss: 0.7774705290794373
#
# step: 9444
# discriminator loss: 0.6685899496078491
# adversarial loss: 0.8266545534133911
#
# step: 9449
# discriminator loss: 0.6868181228637695
# adversarial loss: 1.0486249923706055
#
# step: 9454
# discriminator loss: 0.7176860570907593
# adversarial loss: 0.7537571787834167
#
# step: 9459
# discriminator loss: 0.6641398072242737
# adversarial loss: 0.6577932238578796
#
# step: 9464
# discriminator loss: 0.6800473928451538
# adversarial loss: 0.7786179780960083
#
# step: 9469
# discriminator loss: 0.7119495272636414
# adversarial loss: 0.7799063920974731
#
# step: 9474
# discriminator loss: 0.6838352084159851
# adversarial loss: 0.8305848836898804
#
# step: 9479
# discriminator loss: 0.6507609486579895
# adversarial loss: 0.8591105341911316
#
# step: 9484
# discriminator loss: 0.6598353385925293
# adversarial loss: 0.7954859137535095
#
# step: 9489
# discriminator loss: 0.7110635042190552
# adversarial loss: 0.7273439168930054
#
# step: 9494
# discriminator loss: 0.6928898692131042
# adversarial loss: 0.7829330563545227
#
# step: 9499
# discriminator loss: 0.7047680616378784
# adversarial loss: 0.7609785795211792
#
# step: 9504
# discriminator loss: 0.7041321992874146
# adversarial loss: 1.0395418405532837
#
# step: 9509
# discriminator loss: 0.6777452230453491
# adversarial loss: 0.8081210255622864
#
# step: 9514
# discriminator loss: 0.6961642503738403
# adversarial loss: 0.7235849499702454
#
# step: 9519
# discriminator loss: 0.6297408938407898
# adversarial loss: 1.0631766319274902
#
# step: 9524
# discriminator loss: 0.7088578939437866
# adversarial loss: 0.6591935753822327
#
# step: 9529
# discriminator loss: 0.6902288198471069
# adversarial loss: 0.7733011245727539
#
# step: 9534
# discriminator loss: 0.7088618278503418
# adversarial loss: 0.9929146766662598
#
# step: 9539
# discriminator loss: 0.6872480511665344
# adversarial loss: 0.8110936880111694
#
# step: 9544
# discriminator loss: 0.6459161639213562
# adversarial loss: 1.0823285579681396
#
# step: 9549
# discriminator loss: 0.6672900915145874
# adversarial loss: 0.703199565410614
#
# step: 9554
# discriminator loss: 0.6962534189224243
# adversarial loss: 0.9012821316719055
#
# step: 9559
# discriminator loss: 0.9128075838088989
# adversarial loss: 1.2759746313095093
#
# step: 9564
# discriminator loss: 0.7290817499160767
# adversarial loss: 0.7718809843063354
#
# step: 9569
# discriminator loss: 0.6769844889640808
# adversarial loss: 0.7790426015853882
#
# step: 9574
# discriminator loss: 0.7056509256362915
# adversarial loss: 0.7246074080467224
#
# step: 9579
# discriminator loss: 0.6709861159324646
# adversarial loss: 0.6181700825691223
#
# step: 9584
# discriminator loss: 0.7068800926208496
# adversarial loss: 0.7315906286239624
#
# step: 9589
# discriminator loss: 0.7990585565567017
# adversarial loss: 1.16867995262146
#
# step: 9594
# discriminator loss: 0.6297411918640137
# adversarial loss: 0.5274534225463867
#
# step: 9599
# discriminator loss: 0.6957138776779175
# adversarial loss: 0.9516627192497253
#
# step: 9604
# discriminator loss: 0.6832079887390137
# adversarial loss: 1.1745823621749878
#
# step: 9609
# discriminator loss: 0.6897192597389221
# adversarial loss: 0.7790315747261047
#
# step: 9614
# discriminator loss: 0.7033393383026123
# adversarial loss: 0.8034375905990601
#
# step: 9619
# discriminator loss: 0.6746686697006226
# adversarial loss: 0.8528326153755188
#
# step: 9624
# discriminator loss: 0.6837166547775269
# adversarial loss: 0.7642400860786438
#
# step: 9629
# discriminator loss: 0.7076755166053772
# adversarial loss: 0.7126393914222717
#
# step: 9634
# discriminator loss: 0.6787170171737671
# adversarial loss: 0.7729829549789429
#
# step: 9639
# discriminator loss: 0.6681238412857056
# adversarial loss: 0.865852952003479
#
# step: 9644
# discriminator loss: 0.6622708439826965
# adversarial loss: 0.8816248178482056
#
# step: 9649
# discriminator loss: 0.4916714131832123
# adversarial loss: 4.447239875793457
#
# step: 9654
# discriminator loss: 0.6932751536369324
# adversarial loss: 0.6087466478347778
#
# step: 9659
# discriminator loss: 0.6507090926170349
# adversarial loss: 0.8785457611083984
#
# step: 9664
# discriminator loss: 0.6771050691604614
# adversarial loss: 0.7547274827957153
#
# step: 9669
# discriminator loss: 0.7090446949005127
# adversarial loss: 0.936650276184082
#
# step: 9674
# discriminator loss: 0.6967892646789551
# adversarial loss: 0.8757640719413757
#
# step: 9679
# discriminator loss: 0.6914526224136353
# adversarial loss: 0.900804340839386
#
# step: 9684
# discriminator loss: 0.694768488407135
# adversarial loss: 0.7257897853851318
#
# step: 9689
# discriminator loss: 0.9114216566085815
# adversarial loss: 4.340452194213867
#
# step: 9694
# discriminator loss: 0.6942397356033325
# adversarial loss: 0.7581027746200562
#
# step: 9699
# discriminator loss: 0.6661796569824219
# adversarial loss: 0.7925976514816284
#
# step: 9704
# discriminator loss: 0.672406017780304
# adversarial loss: 0.7324223518371582
#
# step: 9709
# discriminator loss: 0.7811557054519653
# adversarial loss: 0.7433758974075317
#
# step: 9714
# discriminator loss: 0.6846387982368469
# adversarial loss: 0.708915650844574
#
# step: 9719
# discriminator loss: 0.7054823637008667
# adversarial loss: 0.886601448059082
#
# step: 9724
# discriminator loss: 0.7051304578781128
# adversarial loss: 0.86705082654953
#
# step: 9729
# discriminator loss: 0.6839121580123901
# adversarial loss: 0.7446662783622742
#
# step: 9734
# discriminator loss: 0.716331958770752
# adversarial loss: 0.845218300819397
#
# step: 9739
# discriminator loss: 0.7365338802337646
# adversarial loss: 1.043806552886963
#
# step: 9744
# discriminator loss: 0.7627102732658386
# adversarial loss: 0.9472278356552124
#
# step: 9749
# discriminator loss: 0.660378634929657
# adversarial loss: 0.8636037111282349
#
# step: 9754
# discriminator loss: 0.6962947249412537
# adversarial loss: 0.800572395324707
#
# step: 9759
# discriminator loss: 0.6911851167678833
# adversarial loss: 0.9007245302200317
#
# step: 9764
# discriminator loss: 0.6514421105384827
# adversarial loss: 0.7099912762641907
#
# step: 9769
# discriminator loss: 0.6467212438583374
# adversarial loss: 0.8393806219100952
#
# step: 9774
# discriminator loss: 0.6984566450119019
# adversarial loss: 0.8720585107803345
#
# step: 9779
# discriminator loss: 0.7154424786567688
# adversarial loss: 0.6916441321372986
#
# step: 9784
# discriminator loss: 0.6381759643554688
# adversarial loss: 0.7385430335998535
#
# step: 9789
# discriminator loss: 0.7356781363487244
# adversarial loss: 0.6897509098052979
#
# step: 9794
# discriminator loss: 0.7396801710128784
# adversarial loss: 0.7280012369155884
#
# step: 9799
# discriminator loss: 0.7071879506111145
# adversarial loss: 0.8052892684936523
#
# step: 9804
# discriminator loss: 0.734367311000824
# adversarial loss: 0.9891387820243835
#
# step: 9809
# discriminator loss: 0.69422847032547
# adversarial loss: 0.784451961517334
#
# step: 9814
# discriminator loss: 0.671759843826294
# adversarial loss: 0.8459764719009399
#
# step: 9819
# discriminator loss: 0.6061489582061768
# adversarial loss: 0.7759208679199219
#
# step: 9824
# discriminator loss: 1.051048994064331
# adversarial loss: 0.5877119898796082
#
# step: 9829
# discriminator loss: 0.6674830913543701
# adversarial loss: 0.8420768976211548
#
# step: 9834
# discriminator loss: 0.7158071398735046
# adversarial loss: 0.7804728150367737
#
# step: 9839
# discriminator loss: 0.6733369827270508
# adversarial loss: 1.10243821144104
#
# step: 9844
# discriminator loss: 0.6601926684379578
# adversarial loss: 0.8562606573104858
#
# step: 9849
# discriminator loss: 0.7192522287368774
# adversarial loss: 0.9174512624740601
#
# step: 9854
# discriminator loss: 0.6869751811027527
# adversarial loss: 0.8036553263664246
#
# step: 9859
# discriminator loss: 0.7174909710884094
# adversarial loss: 0.7666429281234741
#
# step: 9864
# discriminator loss: 0.690780758857727
# adversarial loss: 0.8421519994735718
#
# step: 9869
# discriminator loss: 0.6306920647621155
# adversarial loss: 0.8890585899353027
#
# step: 9874
# discriminator loss: 0.7259165048599243
# adversarial loss: 1.1949442625045776
#
# step: 9879
# discriminator loss: 0.6821446418762207
# adversarial loss: 0.7887967228889465
#
# step: 9884
# discriminator loss: 0.6904338598251343
# adversarial loss: 0.8053191900253296
#
# step: 9889
# discriminator loss: 0.7214687466621399
# adversarial loss: 0.8574602007865906
#
# step: 9894
# discriminator loss: 0.7000404596328735
# adversarial loss: 0.8104656338691711
#
# step: 9899
# discriminator loss: 0.715356707572937
# adversarial loss: 0.8315393328666687
#
# step: 9904
# discriminator loss: 0.7209276556968689
# adversarial loss: 0.7450108528137207
#
# step: 9909
# discriminator loss: 0.6814193725585938
# adversarial loss: 1.2641322612762451
#
# step: 9914
# discriminator loss: 0.6852067112922668
# adversarial loss: 0.7402723431587219
#
# step: 9919
# discriminator loss: 0.6785205602645874
# adversarial loss: 0.7261659502983093
#
# step: 9924
# discriminator loss: 0.6556330919265747
# adversarial loss: 0.7224552035331726
#
# step: 9929
# discriminator loss: 0.6587012410163879
# adversarial loss: 0.7601674795150757
#
# step: 9934
# discriminator loss: 0.6771058440208435
# adversarial loss: 0.7965347766876221
#
# step: 9939
# discriminator loss: 0.6751351356506348
# adversarial loss: 0.6739338040351868
#
# step: 9944
# discriminator loss: 0.6725099682807922
# adversarial loss: 0.8140031099319458
#
# step: 9949
# discriminator loss: 0.6908473372459412
# adversarial loss: 0.8090271949768066
#
# step: 9954
# discriminator loss: 0.6995980143547058
# adversarial loss: 0.9218932390213013
#
# step: 9959
# discriminator loss: 0.6866500973701477
# adversarial loss: 0.660954475402832
#
# step: 9964
# discriminator loss: 0.6574242115020752
# adversarial loss: 0.8802471160888672
#
# step: 9969
# discriminator loss: 0.8088272213935852
# adversarial loss: 1.1103368997573853
#
# step: 9974
# discriminator loss: 0.7093453407287598
# adversarial loss: 0.8053842782974243
#
# step: 9979
# discriminator loss: 0.675064742565155
# adversarial loss: 0.9041101336479187
#
# step: 9984
# discriminator loss: 0.6476861238479614
# adversarial loss: 1.036844253540039
#
# step: 9989
# discriminator loss: 0.7070538401603699
# adversarial loss: 0.7725644111633301
#
# step: 9994
# discriminator loss: 0.709261417388916
# adversarial loss: 1.026440143585205
#
# step: 9999
# discriminator loss: 0.6555353999137878
# adversarial loss: 0.6348127126693726

# %% [markdown]
# #### 이미지 생성을 통한 시각화

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# - 잠재 공간에서 랜덤한 포인트를 샘플링

# %%
random_latent_vectors = np.random.normal(size=(10, latent_dim))

# %% [markdown]
# - 가짜 이미지로 디코딩

# %%
generated_images = generator.predict(random_latent_vectors)

# %%
print(generated_images.shape)
# Out:
# (10, 32, 32, 3)

# %%
plt.figure(figsize=(20, 8))
for i in range(generated_images.shape[0]):
  plt.subplot(2, 5, i+1)
  img = image.array_to_img(generated_images[i] * 255., scale=False)
  plt.imshow(img)
  plt.xticks([])
  plt.yticks([])

plt.show()
