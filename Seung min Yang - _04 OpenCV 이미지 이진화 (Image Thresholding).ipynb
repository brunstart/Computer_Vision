# %% [markdown]
# - 코드 출처 : https://opencv-python.readthedocs.io/en/latest/index.html

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
from google.colab import files

import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

# %% [markdown]
# # 이미지 이진화 (Image Thesholding)

# %% [markdown]
# ## 기본 임계 처리
# - 이진화 : 영상을 흑/백으로 분류하여 처리하는 것
#
#   - 기준이 되는 임계값을 어떻게 결정할 것인지가 중요한 문제!
#
#   - 임계값보다 크면 백, 작으면 흑이 되는데,
#     기본 임계처리는 사용자가 고정된 임계값을 결정하고 그 결과를 보여주는 단순한 형태
#
# - 기본적으로 이미지의 segmenting의 가장 간단한 방법
#
# - `cv2.threshold()`
#
#   - Parameters
#     - `src` : input image로 single-channel 이미지.(grayscale 이미지)
#
#     - `thresh` : 임계값
#
#     - `maxval` : 임계값을 넘었을 때 적용할 value
#
#     - `type` : thresholding type
#
#   <br>
#
#   - thresholding type
#     - `cv2.THRESH_BINARY`
#       - src(x, y) > thresh 일 때, maxval
#
#       - 그 외, 0
#
#     - `cv2.THRESH_BINARY_INV`
#       - src(x, y) > thresh 일 때, 0
#
#       - 그 외, maxval
#
#     - `cv2.THRESH_TRUNC`
#       - src(x, y) > thresh 일 때, thresh
#
#       - 그 외, src(x, y)
#
#     - `cv2.THRESH_TOZERO`
#       - src(x, y) > thresh 일 때, src(x, y)
#
#       - 그 외, 0
#
#     - `cv2.THRESH_TOZERO_INV`
#       - src(x, y) > thresh 일 때, 0
#
#       - 그 외, src(x, y)

# %% [markdown]
# * letters.jpg
#
#   <img src="https://cdn.pixabay.com/photo/2018/09/26/09/07/letters-3704026_960_720.jpg">
#
#   <sub>[이미지 출처] https://pixabay.com/illustrations/letters-school-learn-alphabet-abc-3704026/</sub>

# %%
files.upload()
# Out:
#      <input type="file" id="files-79ea9f62-8757-4623-bdf3-19d6945fb11b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-79ea9f62-8757-4623-bdf3-19d6945fb11b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving letters.jpg to letters.jpg
# {'letters.jpg': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x05\x03\x04\x04\x04\x03\x05\x04\x04\x04\x05\x05\x05\x06\x07\x0c\x08\x07\x07\x07\x07\x0f\x0b\x0b\t\x0c\x11\x0f\x12\x12\x11\x0f\x11\x11\x13\x16\x1c\x17\x13\x14\x1a\x15\x11\x11\x18!\x18\x1a\x1d\x1d\x1f\x1f\x1f\x13\x17"$"\x1e$\x1c\x1e\x1f\x1e\xff\xdb\x00C"3\x85\xd4\x91\x9b\xb0\xa4G\xb7k&\xff\x00\x0c\xc9.\xb1U\x9d\x06K\x8c\xb7z\xabMx\x12\xf5G\xb3\x8e%\xc8\xca0U\xad\xc7\xb6\xdd\xa8\x82\xa3\x8aZ\xab\x1a2R\x97\xfa\xb0\xce\xadM\x1a\x1b\xe2\xf5\x10Y\xa9\x93\xd9.\xf64\xb8\\\xcfzE\xc56\x95{\xf2V8\xeb\xf6cDY\xb9{\xd2\x04XV\x15\xeb\x8a\x9d\xa6\xc7\xa4i\xf3*\xf9\xba>y\xd3f\xfc&\xac!\xe6\xd8\x92\x99\x8e\xb9\xd0}\xa2\xcd\xdec\xa6\xca\xf7e\xef\xb5\xd9\xa7n\x9d\xf6G\x1fq\xf7\x87\x9e\xe3\xe9\xdc\xbc\xf3``e\x88\x00s\xa0\x1d\xe1\xef\x80{\x8f\xbe\x87\xba\
xad\xda\x17\x9e\xd4[\x19bj.\xebF\x19\xb6\xb64\x8b\xce\x9a\xd9\xa4^\xa1\xcd%\x16\x91\xd0a\x99\xd5\x1b\xe0w\xaa\xb9\xdfW\x85\xa5\\GXf\xa5\xe4|\xa0+bWx\xa9V\xb92t\xef\xd1i\xbc\t>\xc5e\x9e\xaa}L\x13\xeb\xb1\xc8\xb5\xbad\x99oI\xab\xd9\xbfG\x17\xf6&X5N\xaf5\xb1\x83\x10\xe6\xb1\xd7Tk\xf6\x08\x9a\xad_=;$\xd2\xcc\x06\xda\xe5r\x1e\'\x90\xbeg\xb8\xc5wu~\xf9\xbe:\xf7G\xd9\x8c\xa8\xca$\x88\xdb\xaf\xae\xb1d\xaea\xac\x85\xfc\xa4:E\x97\xa6>\xabw\x9c\xe1\x8d7u\xadO1\xb4\xb99{\xb67\xf3\xea\xc7\xdb\x98\xb4*Iz<K\xb2\xeaxZ\xe5\x1c\x80\xd3\x1c\xa9\xd1\xc7\x1dq\xe5s\x03]k\xb6ZE\xec#\\\x18\xed\x88s\x0c\xc2\\\x11\xbc\x88\xad\xb10\x83e\xaaka\xc5a\xa5Fm\xe8\xb6\xde\x10\x93\xdb9\xbaz\xbd*\xb4\x8e\xd1:\x14>E\x02t[u\xc7z\xb7 \xcdY\xbe\xca\xd8\x94[^\x8c\xfcEm\xa3\xd4\x85\x8a\x04Wu9\xe2\x19\xd3i ...

# %%
img = cv2.imread('./letters.jpg', 0)

# %%
img.shape
# Out:
# (426, 640)

# %%
plt.imshow(img, cmap='gray')
plt.show()

# %%
ret, thresh1 = cv2.threshold(img, 128, 255, cv2.THRESH_BINARY)
ret, thresh2 = cv2.threshold(img, 128, 255, cv2.THRESH_BINARY_INV)
ret, thresh3 = cv2.threshold(img, 128, 255, cv2.THRESH_TRUNC)
ret, thresh4 = cv2.threshold(img, 128, 255, cv2.THRESH_TOZERO)
ret, thresh5 = cv2.threshold(img, 128, 255, cv2.THRESH_TOZERO_INV)

# %%
titles = ['Original', 'BINARY', 'BINARY_INV','TRUNC','TOZERO', 'TOZERO_INV']
images = [img, thresh1, thresh2, thresh3, thresh4, thresh5]

# %%
plt.figure(figsize=(14,10))
for i in range(6):
  plt.subplot(2,3,i+1)
  plt.imshow(images[i],'gray')
  plt.title(titles[i])
  plt.xticks([]), plt.yticks([])

plt.show()

# %% [markdown]
# - 이미지
#   - snow.jpg
#
#   <img src="https://cdn.pixabay.com/photo/2014/12/02/22/05/snowflake-554635_960_720.jpg">
#
#   <sub>[이미지 출처] https://pixabay.com/illustrations/snowflake-snow-snowing-winter-cold-554635/</sub>

# %%
files.upload()
# Out:
#      <input type="file" id="files-53edce35-ffae-488a-8be9-f3c4171741b4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-53edce35-ffae-488a-8be9-f3c4171741b4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving snow.jpg to snow.jpg
# {'snow.jpg': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x05\x03\x04\x04\x04\x03\x05\x04\x04\x04\x05\x05\x05\x06\x07\x0c\x08\x07\x07\x07\x07\x0f\x0b\x0b\t\x0c\x11\x0f\x12\x12\x11\x0f\x11\x11\x13\x16\x1c\x17\x13\x14\x1a\x15\x11\x11\x18!\x18\x1a\x1d\x1d\x1f\x1f\x1f\x13\x17"$"\x1e$\x1c\x1e\x1f\x1e\xff\xdb\x00C"y\xaa\x19\xba\xc
5\x1d\xd4\xafF\xf2\xe9\xb8\xbe\x89\xe775\xabU\xa4\xce\x8e\xc9\x8b\x01\x91\xab\xab\xaf\xd7\xe3y\xb1\xd8\x93:\x9f\xe5W\xf9\xf1\x9d\'WX\xc6\xb9\xb0\xce\x93\x18\xe4q%\x02/+\x1bi{\x19\x07\xfa_\x9f\x10%D\xe8~\xa3&\xb5\xdc\x8b\x12\x04fWi33l\xba\xce\xc9\x81IsK\xa8\xcb6\x93`\xda\xa6\x02\x8e\xbc\xa1T\xb2\xafi\x0e\x1a\x8eU\xe4!\xcfk\xe9\n5\xb0\xbc\xc2Y\xceV\xa1gV\x12\xcdV\x93\xab\xe6\xa8\xb4U\xd3\x99\xccZ\xdbD\xb3YOA\xb5\xab\x8c>\xce\xa61\xaeW\xf6\xe4&\x11\x84\xba\xd5Y\xa21\tb\x80\xc3\x97\x90\x9c\x043\xe2\xe3P\\\xe8R\xcf\xac\x13s\xa8\xea`\xa9F\x9a$\xcc5\xcb45S\xa0mj\x981\xc8\xe9g\xe9$A\xcd\xb8\x93\x130\xb5\xf5\\T\x0c\x98\xfd]\xc8\xe88\xd7\xa8i.,\'*R\xd8\xc2\xdb\xa6b\x18\xa4(\x11T\x1b\xd9`\\Ky\xa2\x1dF\x9a\xb4\xc9\xbd\xaf\xd1_eRK\xd2e\xef.s\xe4cjwE\xe4qB\xe2^\xff\x00\xcf="4\xd8\xfd\x15b\xe1=\x0e\x97_\xac\xe1\xe4o\xa8\xac\x8bC\xa3\xcd\xef\x16D$\xfb3\x11\xe7\xc1H\x04\x1a\xb4Nj\x05 J\x15\xcdHm\xf6~\xe3\x1a\x88?I\xca\xcdy\xd3-)\xce\x8aQJ\xde^V/"!F\x92\xb5\x1c\x87\x11\x93J\xcd\xbe0\x19\xd6\x8a~E\xb0\xd9QK\\\x17$!\x11\xa4\x86\x0b\xaal"\x8c\xe2\x10@\xe4GQ\x08r\x90\x9bkTu\x8dq#h\xc8V\x071\xb4\xd5}\x87\xb1\x83a\xe4\xd6\xd9-z\xf3B*=\x18\xe6:\x8a\xf0:\xc9N\x01\x12_\xa3\xf9\x99\xec\xdd_\xf9\x83\xac\xde\xe5!\x9by\x9f.\xb4\xda\xcd\x84\xca%\x90\xb1\xd5j\xb ...

# %%
img2 = cv2.imread('./snow.jpg', 0)

# %%
img2.shape
# Out:
# (426, 640)

# %%
ret, thresh1 = cv2.threshold(img2, 128, 255, cv2.THRESH_BINARY)
ret, thresh2 = cv2.threshold(img2, 128, 255, cv2.THRESH_BINARY_INV)
ret, thresh3 = cv2.threshold(img2, 128, 255, cv2.THRESH_TRUNC)
ret, thresh4 = cv2.threshold(img2, 128, 255, cv2.THRESH_TOZERO)
ret, thresh5 = cv2.threshold(img2, 128, 255, cv2.THRESH_TOZERO_INV)

# %% [markdown]
# - 시각화

# %%
titles = ['Original', 'BINARY', 'BINARY_INV','TRUNC','TOZERO', 'TOZERO_INV']
images = [img2, thresh1, thresh2, thresh3, thresh4, thresh5]

# %%
plt.figure(figsize=(14,10))
for i in range(6):
  plt.subplot(2,3,i+1)
  plt.imshow(images[i],'gray')
  plt.title(titles[i])
  plt.xticks([]), plt.yticks([])

plt.show()

# %% [markdown]
# ## 적응 임계처리
#
# - 이전 단계에서는 임계값을 이미지 전체에 적용하여 처리하기 때문에
#   하나의 이미지에 음영이 다르면 일부 영역이 모두 흰색 또는 검정색으로 보여지게 됨
#
# - 이런 문제를 해결하기 위해서 이미지의 작은 영역별로 thresholding
#
# - `cv2.adaptiveThreshold()`
#
#   - Parameters
#     - `src` : grayscale image
#
#     - `maxValue` : 임계값
#
#     - `adaptiveMethod` : thresholding value를 결정하는 계산 방법
#
#     - `thresholdType` : threshold type
#
#     - `blockSize` : thresholding을 적용할 영역 사이즈
#
#     - `C` : 평균이나 가중평균에서 차감할 값
#
#   <br>
#
#   - Adaptive Method
#     - `cv2.ADAPTIVE_THRESH_MEAN_C` : 주변영역의 평균값으로 결정
#
#     - `cv2.ADAPTIVE_THRESH_GAUSSIAN_C` : 주변영역의 가우시안 값으로 결정

# %%
img = cv2.imread('./letters.jpg',0)

# %%
ret, th1 = cv2.threshold(img, 128, 255, cv2.THRESH_BINARY)

# %%
th2 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 15, 2)
th3 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 15, 2)

# %% [markdown]
# - 시각화

# %%
titles = ['Original', 'Global', 'Mean', 'Gaussian']
images = [img, th1, th2, th3]

# %%
plt.figure(figsize=(14,10))
for i in range(4):
  plt.subplot(2,2,i+1)
  plt.imshow(images[i], cmap='gray')
  plt.title(titles[i])
  plt.xticks([])
  plt.yticks([])

plt.show()

# %% [markdown]
# ## Otsu의 이진화
# - `Otsu의 이진화`(Otsu’s Binarization)란 bimodal image에서 임계값을 자동으로 계산하는 것
#
# - 임계값을 결정하는 가장 일반적인 방법은 trial and error 방식
#
# - bimodal image (히스토그램으로 분석하면 2개의 peak가 있는 이미지)의 경우는 히스토그램에서 임계값을 어느정도 정확히 계산 가능
#
# - `cv2.threshold()` 함수의 flag에 추가로 `cv2.THRESH_STSU` 를 적용.
#   이때 임계값은 0으로 전달

# %% [markdown]
# - 이미지
#   - noise.jpg
#
#   <img src="https://cdn.pixabay.com/photo/2017/01/04/13/09/star-1951963_960_720.jpg">
#
#   <sub>[이미지 출처] https://pixabay.com/illustrations/star-grey-noise-banner-monochrome-1951963/</sub>

# %%
files.upload()
# Out:
#      <input type="file" id="files-66189df9-fb90-47b0-9480-dee5195de623" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-66189df9-fb90-47b0-9480-dee5195de623">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving noise.jpg to noise.jpg
# {'noise.jpg': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x01,\x01,\x00\x00\xff\xe1\x00\x16Exif\x00\x00MM\x00*\x00\x00\x00\x08\x00\x00\x00\x00\x00\x00\xff\xdb\x00C\x00\x03\x02\x02\x02\x02\x02\x03\x02\x02\x02\x03\x03\x03\x03\x04\x06\x04\x04\x04\x04\x04\x08\x06\x06\x05\x06\t\x08\n\n\t\x08\t\t\n\x0c\x0f\x0c\n\x0b\x0e\x0b\t\t\r\x11\r\x0e\x0f\x10\x10\x11\x10\n\x0c\x12\x13\x12\x10\x13\x0f\x10\x10\x10\xff\xdb\x00C\x01\x03\x03\x03\x04\x03\x04\x08\x04\x04\x08\x10\x0b\t\x0b\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\xff\xc0\x00\x11\x08\x01h\x02\x80\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1d\x00\x00\x02\x02\x03\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x03\
8d\xdaL\x0ceJ\x87\xc6\xa1\xcb\x00\x1d\xe5\xbb\xa3\xf1qGj\xcf+\x0e\x91\x08"H\x9e*Rv\xe4$"l\xa5\x8e\xf0\xa2\xb1\r\xe1RF?\x90:j\xaf\x1fZ\xbf#B\xf7\x11Aiq\xff\x00]\xaeW[\x137\xf3`\x12lo#\x11\xe7\xdc\xf8\n\x8a\xec?\xb8F*\x84\xd2[\x97\x83\xe58\xca7\xaeA\nU\x92\xc2Ql\xc6\x9d\xd3\x1c\x81\xa3+ %\x1c\xb2X\xc0\xc2cW\xca\x06\x08Y\xab\x1co\x17w\x97\xb15h\xad\xc1H0!\xc4s?m\x16\x08\n\x18\xa6\\\x9c\xb1\x08B\xc8\xc41\xce\xd9\xd4d\x00%\xe3\xe76Dk^8\xecG\r\x9bd"\xa2\x81\xa6\x17R\xeeN\xd9\x01{hT\xae\xd2dg\x07\xa7y;u`\x96\xbd{s\xd1\xa9\x12\xa4\xcf\x12\xed\xda\xb2s)\x05\x98\xae\xc4\xc8\x18\x85\n\xd8mupH*:\x1d\xb7\xb2>1"Z\xe5\xa5I\x8a\x80\xd0\xc7\xff\x00\x98\x96\xd8\xc8\xdd\xa5\n\xc7\xb2\xa3\xb8\xb1\x01&\x06\xe5\xa4P\xc0\x8c\x99rV9\x95\xe3\xee\xcd+\x8a\xb6\xe4\x91k3\xf6\xdd\xc4\xb2\xac\xcb\x97\xd5\xb6\x8cF\x1f\xd4\x9f\x0c\xfe\xa4\x92\xa3\x00\x16\xb7\xc4\xa0D\x81+\xf1\x89\x14\xa4\xbb\xbd\x99\x820\x89\x9c\x05h\xdc\x16\xd7\xc2\xb1c\xbe\xdf\xc8U@n\xa3r:<u\x06\xe49\n4\xedG=ug\x9et>\xf3\xe1\x84\xfb\x90U\xb2\x85\xd60\xc4dg\xc9\xf1\xd37\xad\xf3U\xfeCc\xec\xd6\xae\xb2M(\x13\xc8-\xc8\xd3\x80\xcd\xbe\x91\x95\xd5\xf2\x15\xc9\x08\x84 R\x07\xe4t\xa5\xe15\x1e\'\xefX\x ...

# %%
img = cv2.imread('./noise.jpg',0)

# %%
img.shape
# Out:
# (360, 640)

# %%
ret1, th1 = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)
ret2, th2 = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
blur = cv2.GaussianBlur(img, (5,5), 0)
ret3, th3 = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# %% [markdown]
# - 시각화

# %%
images = [img, 0, th1, img, 0, th2, blur, 0, th3]
titles = ['Original Image', 'Histogram', 'Global Thresholding', 
          'Original Image', 'Histogram', 'Otsu\'s Thresholding',
          'Gaussian filtered Image', 'Histogram', 'Otsu\'s Thresholding']

# %%
plt.figure(figsize=(14,10))
for i in range(3):
  plt.subplot(3,3,i*3+1)
  plt.imshow(images[i*3], cmap='gray')
  plt.title(titles[i*3])
  plt.xticks([]), plt.yticks([])
  
  plt.subplot(3,3,i*3+2)
  plt.hist(images[i*3].ravel(), 256)
  plt.title(titles[i*3+1]) 
  plt.xticks([]), plt.yticks([])
  
  plt.subplot(3,3,i*3+3)
  plt.imshow(images[i*3+2], cmap='gray')
  plt.title(titles[i*3+2])
  plt.xticks([]), plt.yticks([])  

plt.show()
